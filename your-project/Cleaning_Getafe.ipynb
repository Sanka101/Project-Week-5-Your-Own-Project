# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # statistics Getafe

# %%
x = [{'api': {'results': 16,
   'statistics': {'Shots on Goal': {'home': '2', 'away': '2'},
    'Shots off Goal': {'home': '8', 'away': '4'},
    'Total Shots': {'home': '13', 'away': '8'},
    'Blocked Shots': {'home': '3', 'away': '2'},
    'Shots insidebox': {'home': '10', 'away': '6'},
    'Shots outsidebox': {'home': '3', 'away': '2'},
    'Fouls': {'home': '16', 'away': '15'},
    'Corner Kicks': {'home': '7', 'away': '6'},
    'Offsides': {'home': '1', 'away': '1'},
    'Ball Possession': {'home': '63%', 'away': '37%'},
    'Yellow Cards': {'home': '1', 'away': '5'},
    'Red Cards': {'home': '0', 'away': '1'},
    'Goalkeeper Saves': {'home': '2', 'away': '2'},
    'Total passes': {'home': '532', 'away': '303'},
    'Passes accurate': {'home': '425', 'away': '189'},
    'Passes %': {'home': '80%', 'away': '62%'}}}},
 {'api': {'results': 16,
   'statistics': {'Shots on Goal': {'home': '3', 'away': '3'},
    'Shots off Goal': {'home': '8', 'away': '3'},
    'Total Shots': {'home': '15', 'away': '6'},
    'Blocked Shots': {'home': '4', 'away': '0'},
    'Shots insidebox': {'home': '8', 'away': '5'},
    'Shots outsidebox': {'home': '7', 'away': '1'},
    'Fouls': {'home': '20', 'away': '10'},
    'Corner Kicks': {'home': '7', 'away': '5'},
    'Offsides': {'home': '3', 'away': '3'},
    'Ball Possession': {'home': '43%', 'away': '57%'},
    'Yellow Cards': {'home': '0', 'away': '1'},
    'Red Cards': {'home': '0', 'away': '0'},
    'Goalkeeper Saves': {'home': '2', 'away': '3'},
    'Total passes': {'home': '356', 'away': '478'},
    'Passes accurate': {'home': '234', 'away': '371'},
    'Passes %': {'home': '66%', 'away': '78%'}}}},
 {'api': {'results': 16,
   'statistics': {'Shots on Goal': {'home': '7', 'away': '2'},
    'Shots off Goal': {'home': '4', 'away': '5'},
    'Total Shots': {'home': '11', 'away': '10'},
    'Blocked Shots': {'home': '0', 'away': '3'},
    'Shots insidebox': {'home': '9', 'away': '6'},
    'Shots outsidebox': {'home': '2', 'away': '4'},
    'Fouls': {'home': '14', 'away': '20'},
    'Corner Kicks': {'home': '2', 'away': '4'},
    'Offsides': {'home': '0', 'away': '2'},
    'Ball Possession': {'home': '61%', 'away': '39%'},
    'Yellow Cards': {'home': '1', 'away': '2'},
    'Red Cards': {'home': '0', 'away': '0'},
    'Goalkeeper Saves': {'home': '0', 'away': '6'},
    'Total passes': {'home': '449', 'away': '285'},
    'Passes accurate': {'home': '330', 'away': '166'},
    'Passes %': {'home': '73%', 'away': '58%'}}}},
 {'api': {'results': 16,
   'statistics': {'Shots on Goal': {'home': '4', 'away': '5'},
    'Shots off Goal': {'home': '7', 'away': '1'},
    'Total Shots': {'home': '13', 'away': '7'},
    'Blocked Shots': {'home': '2', 'away': '1'},
    'Shots insidebox': {'home': '5', 'away': '3'},
    'Shots outsidebox': {'home': '8', 'away': '4'},
    'Fouls': {'home': '15', 'away': '14'},
    'Corner Kicks': {'home': '3', 'away': '4'},
    'Offsides': {'home': '4', 'away': '5'},
    'Ball Possession': {'home': '29%', 'away': '71%'},
    'Yellow Cards': {'home': '2', 'away': '4'},
    'Red Cards': {'home': '0', 'away': '0'},
    'Goalkeeper Saves': {'home': '3', 'away': '3'},
    'Total passes': {'home': '272', 'away': '658'},
    'Passes accurate': {'home': '187', 'away': '593'},
    'Passes %': {'home': '69%', 'away': '90%'}}}},
 {'api': {'results': 16,
   'statistics': {'Shots on Goal': {'home':
'}}}},
 {'api': {'results': 16,
   'statistics': {'Shots on Goal': {'home': '2', 'away': '2'},
    'Shots off Goal': {'home': '4', 'away': '10'},
    'Total Shots': {'home': '10', 'away': '15'},
    'Blocked Shots': {'home': '4', 'away': '3'},
    'Shots insidebox': {'home': '7', 'away': '9'},
    'Shots outsidebox': {'home': '3', 'away': '6'},
    'Fouls': {'home': '19', 'away': '21'},
    'Corner Kicks': {'home': '4', 'away': '4'},
    'Offsides': {'home': '1', 'away': '4'},
    'Ball Possession': {'home': '38%', 'away': '62%'},
    'Yellow Cards': {'home': '6', 'away': '3'},
    'Red Cards': {'home': '1', 'away': '0'},
    'Goalkeeper Saves': {'home': '1', 'away': '1'},
    'Total passes': {'home': '261', 'away': '400'},
    'Passes accurate': {'home': '167', 'away': '317'},
    'Passes %': {'home': '64%', 'away': '79%'}}}},
 {'api': {'results': 16,
   'statistics': {'Shots on Goal': {'home': '4', 'away': '1'},
    'Shots off Goal': {'home': '11', 'away': '5'},
    'Total Shots': {'home': '21', 'away': '8'},
    'Blocked Shots': {'home': '6', 'away': '2'},
    'Shots insidebox': {'home': '14', 'away': '6'},
    'Shots outsidebox': {'home': '7', 'away': '2'},
    'Fouls': {'home': '8', 'away': '28'},
    'Corner Kicks': {'home': '9', 'away': '4'},
    'Offsides': {'home': '1', 'away': '3'},
    'Ball Possession': {'home': '69%', 'away': '31%'},
    'Yellow Cards': {'home': '0', 'away': '2'},
    'Red Cards': {'home': '0', 'away': '0'},
    'Goalkeeper Saves': {'home': '0', 'away': '5'},
    'Total passes': {'home': '479', 'away': '212'},
    'Passes accurate': {'home': '386', 'away': '126'},
    'Passes %': {'home': '81%', 'away': '59%'}}}},
 {'api': {'results': 16,
   'statistics': {'Shots on Goal': {'home': '4', 'away': '3'},
    'Shots off Goal': {'home': '5', 'away': '2'},
    'Total Shots': {'home': '11', 'away': '5'},
    'Blocked Shots': {'home': '2', 'away': '0'},
    'Shots insidebox': {'home': '7', 'away': '4'},
    'Shots outsidebox': {'home': '4', 'away': '1'},
    'Fouls': {'home': '13', 'away': '17'},
    'Corner Kicks': {'home': '8', 'away': '2'},
    'Offsides': {'home': '0', 'away': '4'},
    'Ball Possession': {'home': '51%', 'away': '49%'},
    'Yellow Cards': {'home': '3', 'away': '2'},
    'Red Cards': {'home': '0', 'away': '0'},
    'Goalkeeper Saves': {'home': '2', 'away': '4'},
    'Total passes': {'home': '410', 'away': '402'},
    'Passes accurate': {'home': '290', 'away': '291'},
    'Passes %': {'home': '71%', 'away': '72%'}}}},
 {'api': {'results': 16,
   'statistics': {'Shots on Goal': {'home': '2', 'away': '3'},
    'Shots off Goal': {'home': '3', 'away': '6'},
    'Total Shots': {'home': '6', 'away': '11'},
    'Blocked Shots': {'home': '1', 'away': '2'},
    'Shots insidebox': {'home': '5', 'away': '6'},
    'Shots outsidebox': {'home': '1', 'away': '5'},
    'Fouls': {'home': '19', 'away': '12'},
    'Corner Kicks': {'home': '2', 'away': '9'},
    'Offsides': {'home': '2', 'away': '3'},
    'Ball Possession': {'home': '39%', 'away': '61%'},
    'Yellow Cards': {'home': '4', 'away': '1'},
    'Red Cards': {'home': '0', 'away': '0'},
    'Goalkeeper Saves': {'home': '2', 'away': '2'},
    'Total passes': {'home': '306', 'away': '441'},
    'Passes accurate': {'home': '181', 'away': '335'},
    'Passes %': {'home': '59%', 'away': '76%'}}}}]

# %%
x[1]
# Out:
# {'api': {'results': 16,
#   'statistics': {'Shots on Goal': {'home': '3', 'away': '3'},
#    'Shots off Goal': {'home': '8', 'away': '3'},
#    'Total Shots': {'home': '15', 'away': '6'},
#    'Blocked Shots': {'home': '4', 'away': '0'},
#    'Shots insidebox': {'home': '8', 'away': '5'},
#    'Shots outsidebox': {'home': '7', 'away': '1'},
#    'Fouls': {'home': '20', 'away': '10'},
#    'Corner Kicks': {'home': '7', 'away': '5'},
#    'Offsides': {'home': '3', 'away': '3'},
#    'Ball Possession': {'home': '43%', 'away': '57%'},
#    'Yellow Cards': {'home': '0', 'away': '1'},
#    'Red Cards': {'home': '0', 'away': '0'},
#    'Goalkeeper Saves': {'home': '2', 'away': '3'},
#    'Total passes': {'home': '356', 'away': '478'},
#    'Passes accurate': {'home': '234', 'away': '371'},
#    'Passes %': {'home': '66%', 'away': '78%'}}}}

# %%
x[1]['api']['statistics']
# Out:
# {'Shots on Goal': {'home': '3', 'away': '3'},
#  'Shots off Goal': {'home': '8', 'away': '3'},
#  'Total Shots': {'home': '15', 'away': '6'},
#  'Blocked Shots': {'home': '4', 'away': '0'},
#  'Shots insidebox': {'home': '8', 'away': '5'},
#  'Shots outsidebox': {'home': '7', 'away': '1'},
#  'Fouls': {'home': '20', 'away': '10'},
#  'Corner Kicks': {'home': '7', 'away': '5'},
#  'Offsides': {'home': '3', 'away': '3'},
#  'Ball Possession': {'home': '43%', 'away': '57%'},
#  'Yellow Cards': {'home': '0', 'away': '1'},
#  'Red Cards': {'home': '0', 'away': '0'},
#  'Goalkeeper Saves': {'home': '2', 'away': '3'},
#  'Total passes': {'home': '356', 'away': '478'},
#  'Passes accurate': {'home': '234', 'away': '371'},
#  'Passes %': {'home': '66%', 'away': '78%'}}

# %%
x[1]['api']['statistics']
# Out:
# {'Shots on Goal': {'home': '3', 'away': '3'},
#  'Shots off Goal': {'home': '8', 'away': '3'},
#  'Total Shots': {'home': '15', 'away': '6'},
#  'Blocked Shots': {'home': '4', 'away': '0'},
#  'Shots insidebox': {'home': '8', 'away': '5'},
#  'Shots outsidebox': {'home': '7', 'away': '1'},
#  'Fouls': {'home': '20', 'away': '10'},
#  'Corner Kicks': {'home': '7', 'away': '5'},
#  'Offsides': {'home': '3', 'away': '3'},
#  'Ball Possession': {'home': '43%', 'away': '57%'},
#  'Yellow Cards': {'home': '0', 'away': '1'},
#  'Red Cards': {'home': '0', 'away': '0'},
#  'Goalkeeper Saves': {'home': '2', 'away': '3'},
#  'Total passes': {'home': '356', 'away': '478'},
#  'Passes accurate': {'home': '234', 'away': '371'},
#  'Passes %': {'home': '66%', 'away': '78%'}}

# %%
x
# Out:
# [{'api': {'results': 16,
#    'statistics': {'Shots on Goal': {'home': '2', 'away': '2'},
#     'Shots off Goal': {'home': '8', 'away': '4'},
#     'Total Shots': {'home': '13', 'away': '8'},
#     'Blocked Shots': {'home': '3', 'away': '2'},
#     'Shots insidebox': {'home': '10', 'away': '6'},
#     'Shots outsidebox': {'home': '3', 'away': '2'},
#     'Fouls': {'home': '16', 'away': '15'},
#     'Corner Kicks': {'home': '7', 'away': '6'},
#     'Offsides': {'home': '1', 'away': '1'},
#     'Ball Possession': {'home': '63%', 'away': '37%'},
#     'Yellow Cards': {'home': '1', 'away': '5'},
#     'Red Cards': {'home': '0', 'away': '1'},
#     'Goalkeeper Saves': {'home': '2', 'away': '2'},
#     'Total passes': {'home': '532', 'away': '303'},
#     'Passes accurate': {'home': '425', 'away': '189'},
#     'Passes %': {'home': '80%', 'away': '62%'}}}},
#  {'api': {'results': 16,
#    'statistics': {'Shots on Goal': {'home': '3', 'away': '3'},
# ...

# %%
data = []
for i in range(0,38):
    data.append(x[i]['api']['statistics'])
    
data
# Out:
# [{'Shots on Goal': {'home': '2', 'away': '2'},
#   'Shots off Goal': {'home': '8', 'away': '4'},
#   'Total Shots': {'home': '13', 'away': '8'},
#   'Blocked Shots': {'home': '3', 'away': '2'},
#   'Shots insidebox': {'home': '10', 'away': '6'},
#   'Shots outsidebox': {'home': '3', 'away': '2'},
#   'Fouls': {'home': '16', 'away': '15'},
#   'Corner Kicks': {'home': '7', 'away': '6'},
#   'Offsides': {'home': '1', 'away': '1'},
#   'Ball Possession': {'home': '63%', 'away': '37%'},
#   'Yellow Cards': {'home': '1', 'away': '5'},
#   'Red Cards': {'home': '0', 'away': '1'},
#   'Goalkeeper Saves': {'home': '2', 'away': '2'},
#   'Total passes': {'home': '532', 'away': '303'},
#   'Passes accurate': {'home': '425', 'away': '189'},
#   'Passes %': {'home': '80%', 'away': '62%'}},
#  {'Shots on Goal': {'home': '3', 'away': '3'},
#   'Shots off Goal': {'home': '8', 'away': '3'},
#   'Total Shots': {'home': '15', 'away': '6'},
#   'Blocked Shots': {'home': '4', 'away': '0'},
# ...

# %%
# list of 38 dict
raw_data = pd.DataFrame(data)

# %%
raw_data.to_csv('Raw_Data/getafe_stats_ha.csv', sep= ',')

# %%
y = [{'team_id': 531,
  'team_name': 'Athletic Club',
  'logo': 'https://media.api-sports.io/football/teams/531.png'},
 {'team_id': 546,
  'team_name': 'Getafe',
  'logo': 'https://media.api-sports.io/football/teams/546.png'},
 {'team_id': 537,
  'team_name': 'Leganes',
  'logo': 'https://media.api-sports.io/football/teams/537.png'},
 {'team_id': 546,
  'team_name': 'Getafe',
  'logo': 'https://media.api-sports.io/football/teams/546.png'},
 {'team_id': 538,
  'team_name': 'Celta Vigo',
  'logo': 'https://media.api-sports.io/football/teams/538.png'},
 {'team_id': 546,
  'team_name': 'Getafe',
  'logo': 'https://media.api-sports.io/football/teams/546.png'},
 {'team_id': 544,
  'team_name': 'Deportivo La Coruna',
  'logo': 'https://media.api-sports.io/football/teams/544.png'},
 {'team_id': 546,
  'team_name': 'Getafe',
  'logo': 'https://media.api-sports.io/football/teams/546.png'},
 {'team_id': 539,
  'team_name': 'Levante',
  'logo': 'https://media.api-sports.io/football/teams/539.png'},
 {'team_id': 546,
  'team_name': 'Getafe',
  'logo': 'https://media.api-sports.io/football/teams/546.png'},
 {'team_id': 543,
  'team_name': 'Real Betis',
  'logo': 'https://media.api-sports.io/football/teams/543.png'},
 {'team_id': 546,
  'team_name': 'Getafe',
  'logo': 'https://media.api-sports.io/football/teams/546.png'},
 {'team_id': 540,
  'team_name': 'Espanyol',
  'logo': 'https://media.api-sports.io/football/teams/540.png'},
 {'team_id': 546,
  'team_name': 'Getafe',
  'logo': 'https://media.api-sports.io/football/teams/546.png'},
 {'team_id': 546,
  'team_name': 'Getafe',
  'logo': 'https://media.api-sports.io/football/teams/546.png'},
 {'team_id': 547,
  'team_name': 'Girona',
  'logo': 'https://media.api-sports.io/football/teams/547.png'},
 {'team_id': 546,
  'team_name': 'Getafe',
  'logo': 'https://media.api-sports.io/football/teams/546.png'},
 {'team_id': 530,
  'team_name': 'Atletico Madrid',
  'logo': 'https://media.api-sports.io/football/teams/530.png'},
 {'team_id': 546,
  'team_name': 'Getafe',
  'logo': 'https://media.api-sports.io/football/teams/546.png'},
 {'team_id': 546,
  'team_name': 'Getafe',
  'logo': 'https://media.api-sports.io/football/teams/546.png'},
 {'team_id': 536,
  'team_name': 'Sevilla',
  'logo': 'https://media.api-sports.io/football/teams/536.png'},
 {'team_id': 546,
  'team_name': 'Getafe',
  'logo': 'https://media.api-sports.io/football/teams/546.png'},
 {'team_id': 529,
  'team_name': 'Barcelona',
  'logo': 'https://media.api-sports.io/football/teams/529.png'},
 {'team_id': 546,
  'team_name': 'Getafe',
  'logo': 'https://media.api-sports.io/football/teams/546.png'},
 {'team_id': 533,
  'team_name': 'Villarreal',
  'logo': 'https://media.api-sports.io/football/teams/533.png'},
 {'team_id': 546,
  'team_name': 'Getafe',
  'logo': 'https://media.api-sports.io/football/teams/546.png'},
 {'team_id': 541,
  'team_name': 'Real Madrid',
  'logo': 'https://media.api-sports.io/football/teams/541.png'},
 {'team_id': 546,
  'team_name': 'Getafe',
  'logo': 'https://media.api-sports.io/football/teams/546.png'},
 {'team_id': 548,
  'team_name': 'Real Sociedad',
  'logo': 'https://media.api-sports.io/football/teams/548.png'},
 {'team_id': 546,
  'team_name': 'Getafe',
  'logo': 'https://media.api-sports.io/football/teams/546.png'},
 {'team_id': 542,
  'team_name': 'Alaves',
  'logo': 'https://media.api-sports.io/football/teams/542.png'},
 {'team_id': 546,
  'team_name': 'Getafe',
  'logo': 'https://media.api-sports.io/football/teams/546.png'},
 {'team_id': 532,
  'team_name': 'Valencia',
  'logo': 'https://media.api-sports.io/football/teams/532.png'},
 {'team_id': 545,
  'team_name': 'Eibar',
  'logo': 'https://media.api-sports.io/football/teams/545.png'},
 {'team_id': 546,
  'team_name': 'Getafe',
  'logo': 'https://media.api-sports.io/football/teams/546.png'},
 {'team_id': 534,
  'team_name': 'Las Palmas',
  'logo': 'https://media.api-sports.io/football/teams/534.png'},
 {'team_id': 546,
  'team_name': 'Getafe',
  'logo': 'https://media.api-sports.io/football/teams/546.png'},
 {'team_id': 535,
  'team_name': 'Malaga',
  'logo': 'https://media.api-sports.io/football/teams/535.png'}]

# %%
raw_hometeam = pd.DataFrame(y)

# %%
raw_hometeam.to_csv('Raw_Data/getafe_stats_hometeam.csv', sep= ',')

# %%
overall = {'api': {'results': 1,
  'statistics': {'matchs': {'matchsPlayed': {'home': 19,
     'away': 19,
     'total': 38},
    'wins': {'home': 9, 'away': 6, 'total': 15},
    'draws': {'home': 4, 'away': 6, 'total': 10},
    'loses': {'home': 6, 'away': 7, 'total': 13}},
   'goals': {'goalsFor': {'home': 26, 'away': 16, 'total': 42},
    'goalsAgainst': {'home': 13, 'away': 20, 'total': 33}},
   'goalsAvg': {'goalsFor': {'home': '1.4', 'away': '0.8', 'total': '1.1'},
    'goalsAgainst': {'home': '0.7', 'away': '1.1', 'total': '0.9'}}}}}

# %%
overall = overall['api']['statistics']

# %%
overall = pd.DataFrame(overall)

# %%
overall.to_csv('Raw_Data/getafe_stats_overall.csv', sep= ',')

# %%
overall
# Out:
#                                              matchs  \
# matchsPlayed  {'home': 19, 'away': 19, 'total': 38}
# wins            {'home': 9, 'away': 6, 'total': 15}
# draws           {'home': 4, 'away': 6, 'total': 10}
# loses           {'home': 6, 'away': 7, 'total': 13}
# goalsFor                                        NaN
# goalsAgainst                                    NaN
#
#                                               goals  \
# matchsPlayed                                    NaN
# wins                                            NaN
# draws                                           NaN
# loses                                           NaN
# goalsFor      {'home': 26, 'away': 16, 'total': 42}
# goalsAgainst  {'home': 13, 'away': 20, 'total': 33}
#
#                                                     goalsAvg
# matchsPlayed                                             NaN
# wins                                                     NaN
# ...

# %%
z = {'api': {'results': 38,
  'fixtures': [{'fixture_id': 9882,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2017-08-20T16:15:00+00:00',
    'event_timestamp': 1503245700,
    'firstHalfStart': 1503245700,
    'secondHalfStart': 1503249300,
    'round': 'Regular Season - 1',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'San Mamés',
    'referee': 'Mario Melero Lopez, Spain',
    'homeTeam': {'team_id': 531,
     'team_name': 'Athletic Club',
     'logo': 'https://media.api-sports.io/football/teams/531.png'},
    'awayTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'goalsHomeTeam': 0,
    'goalsAwayTeam': 0,
    'score': {'halftime': '0-0',
     'fulltime': '0-0',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9869,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2017-08-27T18:15:00+00:00',
    'event_timestamp': 1503857700,
    'firstHalfStart': 1503857700,
    'secondHalfStart': 1503861300,
    'round': 'Regular Season - 2',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Coliseum Alfonso Pérez',
    'referee': 'Alberto Undiano, Spain',
    'homeTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'awayTeam': {'team_id': 536,
     'team_name': 'Sevilla',
     'logo': 'https://media.api-sports.io/football/teams/536.png'},
    'goalsHomeTeam': 0,
    'goalsAwayTeam': 1,
    'score': {'halftime': '0-0',
     'fulltime': '0-1',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9867,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2017-09-08T19:00:00+00:00',
    'event_timestamp': 1504897200,
    'firstHalfStart': 1504897200,
    'secondHalfStart': 1504900800,
    'round': 'Regular Season - 3',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Municipal de Butarque',
    'referee': 'Alfonso Alvarez Izquierdo, Spain',
    'homeTeam': {'team_id': 537,
     'team_name': 'Leganes',
     'logo': 'https://media.api-sports.io/football/teams/537.png'},
    'awayTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'goalsHomeTeam': 1,
    'goalsAwayTeam': 2,
    'score': {'halftime': '0-1',
     'fulltime': '1-2',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9855,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2017-09-16T14:15:00+00:00',
    'event_timestamp': 1505571300,
    'firstHalfStart': 1505571300,
    'secondHalfStart': 1505574900,
    'round': 'Regular Season - 4',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Coliseum Alfonso Pérez',
    'referee': 'David Fernandez Borbalan, Spain',
    'homeTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'awayTeam': {'team_id': 529,
     'team_name': 'Barcelona',
     'logo': 'https://media.api-sports.io/football/teams/529.png'},
    'goalsHomeTeam': 1,
    'goalsAwayTeam': 2,
    'score': {'halftime': '1-0',
     'fulltime': '1-2',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9839,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2017-09-21T19:00:00+00:00',
    'event_timestamp': 1506020400,
    'firstHalfStart': 1506020400,
    'secondHalfStart': 1506024000,
    'round': 'Regular Season - 5',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Municipal de Balaídos',
    'referee': 'Daniel Jesus Trujillo Suarez, Spain',
    'homeTeam': {'team_id': 538,
     'team_name': 'Celta Vigo',
     'logo': 'https://media.api-sports.io/football/teams/538.png'},
    'awayTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'goalsHomeTeam': 1,
    'goalsAwayTeam': 1,
    'score': {'halftime': '1-0',
     'fulltime': '1-1',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9832,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2017-09-24T14:15:00+00:00',
    'event_timestamp': 1506262500,
    'firstHalfStart': 1506262500,
    'secondHalfStart': 1506266100,
    'round': 'Regular Season - 6',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Coliseum Alfonso Pérez',
    'referee': 'Ignacio Iglesias Villanueva, Spain',
    'homeTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'awayTeam': {'team_id': 533,
     'team_name': 'Villarreal',
     'logo': 'https://media.api-sports.io/football/teams/533.png'},
    'goalsHomeTeam': 4,
    'goalsAwayTeam': 0,
    'score': {'halftime': '0-0',
     'fulltime': '4-0',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9826,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2017-09-30T11:00:00+00:00',
    'event_timestamp': 1506769200,
    'firstHalfStart': 1506769200,
    'secondHalfStart': 1506772800,
    'round': 'Regular Season - 7',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Estadio de Riazor',
    'referee': 'Javier Estrada Fernandez, Spain',
    'homeTeam': {'team_id': 544,
     'team_name': 'Deportivo La Coruna',
     'logo': 'https://media.api-sports.io/football/teams/544.png'},
    'awayTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'goalsHomeTeam': 2,
    'goalsAwayTeam': 1,
    'score': {'halftime': '0-0',
     'fulltime': '2-1',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9815,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2017-10-14T14:15:00+00:00',
    'event_timestamp': 1507990500,
    'firstHalfStart': 1507990500,
    'secondHalfStart': 1507994100,
    'round': 'Regular Season - 8',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Coliseum Alfonso Pérez',
    'referee': 'Juan Martinez Munuera, Spain',
    'homeTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'awayTeam': {'team_id': 541,
     'team_name': 'Real Madrid',
     'logo': 'https://media.api-sports.io/football/teams/541.png'},
    'goalsHomeTeam': 1,
    'goalsAwayTeam': 2,
    'score': {'halftime': '0-1',
     'fulltime': '1-2',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9807,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2017-10-21T11:00:00+00:00',
    'event_timestamp': 1508583600,
    'firstHalfStart': 1508583600,
    'secondHalfStart': 1508587200,
    'round': 'Regular Season - 9',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Ciutat de València',
    'referee': 'Ricardo De Burgos Bengoetxea, Spain',
    'homeTeam': {'team_id': 539,
     'team_name': 'Levante',
     'logo': 'https://media.api-sports.io/football/teams/539.png'},
    'awayTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'goalsHomeTeam': 1,
    'goalsAwayTeam': 1,
    'score': {'halftime': '0-0',
     'fulltime': '1-1',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9793,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2017-10-29T11:00:00+00:00',
    'event_timestamp': 1509274800,
    'firstHalfStart': 1509274800,
    'secondHalfStart': 1509278400,
    'round': 'Regular Season - 10',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Coliseum Alfonso Pérez',
    'referee': 'Jose Maria Sanchez Martinez, Spain',
    'homeTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'awayTeam': {'team_id': 548,
     'team_name': 'Real Sociedad',
     'logo': 'https://media.api-sports.io/football/teams/548.png'},
    'goalsHomeTeam': 2,
    'goalsAwayTeam': 1,
    'score': {'halftime': '0-1',
     'fulltime': '2-1',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9787,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2017-11-03T20:00:00+00:00',
    'event_timestamp': 1509739200,
    'firstHalfStart': 1509739200,
    'secondHalfStart': 1509742800,
    'round': 'Regular Season - 11',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Benito Villamarín',
    'referee': 'Antonio Mateu, Spain',
    'homeTeam': {'team_id': 543,
     'team_name': 'Real Betis',
     'logo': 'https://media.api-sports.io/football/teams/543.png'},
    'awayTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'goalsHomeTeam': 2,
    'goalsAwayTeam': 2,
    'score': {'halftime': '0-2',
     'fulltime': '2-2',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9776,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2017-11-18T12:00:00+00:00',
    'event_timestamp': 1511006400,
    'firstHalfStart': 1511006400,
    'secondHalfStart': 1511010000,
    'round': 'Regular Season - 12',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Coliseum Alfonso Pérez',
    'referee': 'Santiago Jaime Latre, Spain',
    'homeTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'awayTeam': {'team_id': 542,
     'team_name': 'Alaves',
     'logo': 'https://media.api-sports.io/football/teams/542.png'},
    'goalsHomeTeam': 4,
    'goalsAwayTeam': 1,
    'score': {'halftime': '2-0',
     'fulltime': '4-1',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9758,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2017-11-27T20:00:00+00:00',
    'event_timestamp': 1511812800,
    'firstHalfStart': 1511812800,
    'secondHalfStart': 1511816400,
    'round': 'Regular Season - 13',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'RCDE Stadium',
    'referee': 'Juan Martinez Munuera, Spain',
    'homeTeam': {'team_id': 540,
     'team_name': 'Espanyol',
     'logo': 'https://media.api-sports.io/football/teams/540.png'},
    'awayTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'goalsHomeTeam': 1,
    'goalsAwayTeam': 0,
    'score': {'halftime': '0-0',
     'fulltime': '1-0',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9751,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2017-12-03T15:15:00+00:00',
    'event_timestamp': 1512314100,
    'firstHalfStart': 1512314100,
    'secondHalfStart': 1512317700,
    'round': 'Regular Season - 14',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Coliseum Alfonso Pérez',
    'referee': 'David Medie Jimenez, Spain',
    'homeTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'awayTeam': {'team_id': 532,
     'team_name': 'Valencia',
     'logo': 'https://media.api-sports.io/football/teams/532.png'},
    'goalsHomeTeam': 1,
    'goalsAwayTeam': 0,
    'score': {'halftime': '0-0',
     'fulltime': '1-0',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9746,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2017-12-09T12:00:00+00:00',
    'event_timestamp': 1512820800,
    'firstHalfStart': 1512820800,
    'secondHalfStart': 1512824400,
    'round': 'Regular Season - 15',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Coliseum Alfonso Pérez',
    'referee': 'Javier Alberola Rojas, Spain',
    'homeTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'awayTeam': {'team_id': 545,
     'team_name': 'Eibar',
     'logo': 'https://media.api-sports.io/football/teams/545.png'},
    'goalsHomeTeam': 0,
    'goalsAwayTeam': 0,
    'score': {'halftime': '0-0',
     'fulltime': '0-0',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9733,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2017-12-17T11:00:00+00:00',
    'event_timestamp': 1513508400,
    'firstHalfStart': 1513508400,
    'secondHalfStart': 1513512000,
    'round': 'Regular Season - 16',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Estadi Montilivi',
    'referee': 'Alberto Undiano, Spain',
    'homeTeam': {'team_id': 547,
     'team_name': 'Girona',
     'logo': 'https://media.api-sports.io/football/teams/547.png'},
    'awayTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'goalsHomeTeam': 1,
    'goalsAwayTeam': 0,
    'score': {'halftime': '1-0',
     'fulltime': '1-0',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9727,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2017-12-20T18:30:00+00:00',
    'event_timestamp': 1513794600,
    'firstHalfStart': 1513794600,
    'secondHalfStart': 1513798200,
    'round': 'Regular Season - 17',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Coliseum Alfonso Pérez',
    'referee': 'Ricardo De Burgos Bengoetxea, Spain',
    'homeTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'awayTeam': {'team_id': 534,
     'team_name': 'Las Palmas',
     'logo': 'https://media.api-sports.io/football/teams/534.png'},
    'goalsHomeTeam': 2,
    'goalsAwayTeam': 0,
    'score': {'halftime': '2-0',
     'fulltime': '2-0',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9718,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2018-01-06T12:00:00+00:00',
    'event_timestamp': 1515240000,
    'firstHalfStart': 1515240000,
    'secondHalfStart': 1515243600,
    'round': 'Regular Season - 18',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Estadio Wanda Metropolitano',
    'referee': 'Jose Luis Munuera Montero, Spain',
    'homeTeam': {'team_id': 530,
     'team_name': 'Atletico Madrid',
     'logo': 'https://media.api-sports.io/football/teams/530.png'},
    'awayTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'goalsHomeTeam': 2,
    'goalsAwayTeam': 0,
    'score': {'halftime': '1-0',
     'fulltime': '2-0',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9708,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2018-01-12T20:00:00+00:00',
    'event_timestamp': 1515787200,
    'firstHalfStart': 1515787200,
    'secondHalfStart': 1515790800,
    'round': 'Regular Season - 19',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Coliseum Alfonso Pérez',
    'referee': 'Juan Martinez Munuera, Spain',
    'homeTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'awayTeam': {'team_id': 535,
     'team_name': 'Malaga',
     'logo': 'https://media.api-sports.io/football/teams/535.png'},
    'goalsHomeTeam': 1,
    'goalsAwayTeam': 0,
    'score': {'halftime': '0-0',
     'fulltime': '1-0',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9698,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2018-01-19T20:00:00+00:00',
    'event_timestamp': 1516392000,
    'firstHalfStart': 1516392000,
    'secondHalfStart': 1516395600,
    'round': 'Regular Season - 20',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Coliseum Alfonso Pérez',
    'referee': 'Jesus Gil Manzano, Spain',
    'homeTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'awayTeam': {'team_id': 531,
     'team_name': 'Athletic Club',
     'logo': 'https://media.api-sports.io/football/teams/531.png'},
    'goalsHomeTeam': 2,
    'goalsAwayTeam': 2,
    'score': {'halftime': '1-1',
     'fulltime': '2-2',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9681,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2018-01-28T17:30:00+00:00',
    'event_timestamp': 1517160600,
    'firstHalfStart': 1517160600,
    'secondHalfStart': 1517164200,
    'round': 'Regular Season - 21',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Ramón Sánchez-Pizjuán',
    'referee': 'Javier Alberola Rojas, Spain',
    'homeTeam': {'team_id': 536,
     'team_name': 'Sevilla',
     'logo': 'https://media.api-sports.io/football/teams/536.png'},
    'awayTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'goalsHomeTeam': 1,
    'goalsAwayTeam': 1,
    'score': {'halftime': '0-0',
     'fulltime': '1-1',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9673,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2018-02-04T11:00:00+00:00',
    'event_timestamp': 1517742000,
    'firstHalfStart': 1517742000,
    'secondHalfStart': 1517745600,
    'round': 'Regular Season - 22',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Coliseum Alfonso Pérez',
    'referee': 'Alfonso Alvarez Izquierdo, Spain',
    'homeTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'awayTeam': {'team_id': 537,
     'team_name': 'Leganes',
     'logo': 'https://media.api-sports.io/football/teams/537.png'},
    'goalsHomeTeam': 0,
    'goalsAwayTeam': 0,
    'score': {'halftime': '0-0',
     'fulltime': '0-0',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9662,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2018-02-11T15:15:00+00:00',
    'event_timestamp': 1518362100,
    'firstHalfStart': 1518362100,
    'secondHalfStart': 1518365700,
    'round': 'Regular Season - 23',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Camp Nou',
    'referee': 'David Fernandez Borbalan, Spain',
    'homeTeam': {'team_id': 529,
     'team_name': 'Barcelona',
     'logo': 'https://media.api-sports.io/football/teams/529.png'},
    'awayTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'goalsHomeTeam': 0,
    'goalsAwayTeam': 0,
    'score': {'halftime': '0-0',
     'fulltime': '0-0',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9649,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2018-02-19T20:00:00+00:00',
    'event_timestamp': 1519070400,
    'firstHalfStart': 1519070400,
    'secondHalfStart': 1519074000,
    'round': 'Regular Season - 24',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Coliseum Alfonso Pérez',
    'referee': 'Pablo Gonzales Fuertes, Spain',
    'homeTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'awayTeam': {'team_id': 538,
     'team_name': 'Celta Vigo',
     'logo': 'https://media.api-sports.io/football/teams/538.png'},
    'goalsHomeTeam': 3,
    'goalsAwayTeam': 0,
    'score': {'halftime': '1-0',
     'fulltime': '3-0',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9642,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2018-02-25T11:00:00+00:00',
    'event_timestamp': 1519556400,
    'firstHalfStart': 1519556400,
    'secondHalfStart': 1519560000,
    'round': 'Regular Season - 25',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Estadio de la Cerámica',
    'referee': 'Jose Maria Sanchez Martinez, Spain',
    'homeTeam': {'team_id': 533,
     'team_name': 'Villarreal',
     'logo': 'https://media.api-sports.io/football/teams/533.png'},
    'awayTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'goalsHomeTeam': 1,
    'goalsAwayTeam': 0,
    'score': {'halftime': '1-0',
     'fulltime': '1-0',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9634,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2018-02-28T18:30:00+00:00',
    'event_timestamp': 1519842600,
    'firstHalfStart': 1519842600,
    'secondHalfStart': 1519846200,
    'round': 'Regular Season - 26',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Coliseum Alfonso Pérez',
    'referee': 'Jose Luis Munuera Montero, Spain',
    'homeTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'awayTeam': {'team_id': 544,
     'team_name': 'Deportivo La Coruna',
     'logo': 'https://media.api-sports.io/football/teams/544.png'},
    'goalsHomeTeam': 3,
    'goalsAwayTeam': 0,
    'score': {'halftime': '2-0',
     'fulltime': '3-0',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9623,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2018-03-03T19:45:00+00:00',
    'event_timestamp': 1520106300,
    'firstHalfStart': 1520106300,
    'secondHalfStart': 1520109900,
    'round': 'Regular Season - 27',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Santiago Bernabéu',
    'referee': 'Mario Melero Lopez, Spain',
    'homeTeam': {'team_id': 541,
     'team_name': 'Real Madrid',
     'logo': 'https://media.api-sports.io/football/teams/541.png'},
    'awayTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'goalsHomeTeam': 3,
    'goalsAwayTeam': 1,
    'score': {'halftime': '2-0',
     'fulltime': '3-1',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9614,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2018-03-10T17:30:00+00:00',
    'event_timestamp': 1520703000,
    'firstHalfStart': 1520703000,
    'secondHalfStart': 1520706600,
    'round': 'Regular Season - 28',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Coliseum Alfonso Pérez',
    'referee': 'Daniel Jesus Trujillo Suarez, Spain',
    'homeTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'awayTeam': {'team_id': 539,
     'team_name': 'Levante',
     'logo': 'https://media.api-sports.io/football/teams/539.png'},
    'goalsHomeTeam': 0,
    'goalsAwayTeam': 1,
    'score': {'halftime': '0-0',
     'fulltime': '0-1',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9604,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2018-03-17T17:30:00+00:00',
    'event_timestamp': 1521307800,
    'firstHalfStart': 1521307800,
    'secondHalfStart': 1521311400,
    'round': 'Regular Season - 29',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Anoeta',
    'referee': 'Javier Estrada Fernandez, Spain',
    'homeTeam': {'team_id': 548,
     'team_name': 'Real Sociedad',
     'logo': 'https://media.api-sports.io/football/teams/548.png'},
    'awayTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'goalsHomeTeam': 1,
    'goalsAwayTeam': 2,
    'score': {'halftime': '1-1',
     'fulltime': '1-2',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9588,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2018-04-02T19:00:00+00:00',
    'event_timestamp': 1522695600,
    'firstHalfStart': 1522695600,
    'secondHalfStart': 1522699200,
    'round': 'Regular Season - 30',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Coliseum Alfonso Pérez',
    'referee': 'Alberto Undiano, Spain',
    'homeTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'awayTeam': {'team_id': 543,
     'team_name': 'Real Betis',
     'logo': 'https://media.api-sports.io/football/teams/543.png'},
    'goalsHomeTeam': 0,
    'goalsAwayTeam': 1,
    'score': {'halftime': '0-0',
     'fulltime': '0-1',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9586,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2018-04-07T11:00:00+00:00',
    'event_timestamp': 1523098800,
    'firstHalfStart': 1523098800,
    'secondHalfStart': 1523102400,
    'round': 'Regular Season - 31',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Estadio de Mendizorroza',
    'referee': 'Santiago Jaime Latre, Spain',
    'homeTeam': {'team_id': 542,
     'team_name': 'Alaves',
     'logo': 'https://media.api-sports.io/football/teams/542.png'},
    'awayTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'goalsHomeTeam': 2,
    'goalsAwayTeam': 0,
    'score': {'halftime': '0-0',
     'fulltime': '2-0',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9569,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2018-04-15T16:30:00+00:00',
    'event_timestamp': 1523809800,
    'firstHalfStart': 1523809800,
    'secondHalfStart': 1523813400,
    'round': 'Regular Season - 32',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Coliseum Alfonso Pérez',
    'referee': 'Mario Melero Lopez, Spain',
    'homeTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'awayTeam': {'team_id': 540,
     'team_name': 'Espanyol',
     'logo': 'https://media.api-sports.io/football/teams/540.png'},
    'goalsHomeTeam': 1,
    'goalsAwayTeam': 0,
    'score': {'halftime': '0-0',
     'fulltime': '1-0',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9564,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2018-04-18T17:30:00+00:00',
    'event_timestamp': 1524072600,
    'firstHalfStart': 1524072600,
    'secondHalfStart': 1524076200,
    'round': 'Regular Season - 33',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Mestalla',
    'referee': 'Ricardo De Burgos Bengoetxea, Spain',
    'homeTeam': {'team_id': 532,
     'team_name': 'Valencia',
     'logo': 'https://media.api-sports.io/football/teams/532.png'},
    'awayTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'goalsHomeTeam': 1,
    'goalsAwayTeam': 2,
    'score': {'halftime': '0-1',
     'fulltime': '1-2',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9556,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2018-04-21T11:00:00+00:00',
    'event_timestamp': 1524308400,
    'firstHalfStart': 1524308400,
    'secondHalfStart': 1524312000,
    'round': 'Regular Season - 34',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Ipurua Municipal Stadium',
    'referee': 'Ignacio Iglesias Villanueva, Spain',
    'homeTeam': {'team_id': 545,
     'team_name': 'Eibar',
     'logo': 'https://media.api-sports.io/football/teams/545.png'},
    'awayTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'goalsHomeTeam': 0,
    'goalsAwayTeam': 1,
    'score': {'halftime': '0-1',
     'fulltime': '0-1',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9544,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2018-04-29T10:00:00+00:00',
    'event_timestamp': 1524996000,
    'firstHalfStart': 1524996000,
    'secondHalfStart': 1524999600,
    'round': 'Regular Season - 35',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Coliseum Alfonso Pérez',
    'referee': 'Alejandro Hernandez, Spain',
    'homeTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'awayTeam': {'team_id': 547,
     'team_name': 'Girona',
     'logo': 'https://media.api-sports.io/football/teams/547.png'},
    'goalsHomeTeam': 1,
    'goalsAwayTeam': 1,
    'score': {'halftime': '1-1',
     'fulltime': '1-1',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9532,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2018-05-06T16:30:00+00:00',
    'event_timestamp': 1525624200,
    'firstHalfStart': 1525624200,
    'secondHalfStart': 1525627800,
    'round': 'Regular Season - 36',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Gran Canaria',
    'referee': 'Alberto Undiano, Spain',
    'homeTeam': {'team_id': 534,
     'team_name': 'Las Palmas',
     'logo': 'https://media.api-sports.io/football/teams/534.png'},
    'awayTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'goalsHomeTeam': 0,
    'goalsAwayTeam': 1,
    'score': {'halftime': '0-0',
     'fulltime': '0-1',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9525,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2018-05-12T16:30:00+00:00',
    'event_timestamp': 1526142600,
    'firstHalfStart': 1526142600,
    'secondHalfStart': 1526146200,
    'round': 'Regular Season - 37',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Coliseum Alfonso Pérez',
    'referee': 'Javier Alberola Rojas, Spain',
    'homeTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'awayTeam': {'team_id': 530,
     'team_name': 'Atletico Madrid',
     'logo': 'https://media.api-sports.io/football/teams/530.png'},
    'goalsHomeTeam': 0,
    'goalsAwayTeam': 1,
    'score': {'halftime': '0-1',
     'fulltime': '0-1',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 9514,
    'league_id': 30,
    'league': {'name': 'Primera Division',
     'country': 'Spain',
     'logo': 'https://media.api-sports.io/football/leagues/140.png',
     'flag': 'https://media.api-sports.io/flags/es.svg'},
    'event_date': '2018-05-19T16:30:00+00:00',
    'event_timestamp': 1526747400,
    'firstHalfStart': 1526747400,
    'secondHalfStart': 1526751000,
    'round': 'Regular Season - 38',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'La Rosaleda',
    'referee': 'Daniel Jesus Trujillo Suarez, Spain',
    'homeTeam': {'team_id': 535,
     'team_name': 'Malaga',
     'logo': 'https://media.api-sports.io/football/teams/535.png'},
    'awayTeam': {'team_id': 546,
     'team_name': 'Getafe',
     'logo': 'https://media.api-sports.io/football/teams/546.png'},
    'goalsHomeTeam': 0,
    'goalsAwayTeam': 1,
    'score': {'halftime': '0-0',
     'fulltime': '0-1',
     'extratime': None,
     'penalty': None}}]}}

# %%
end_score = []
for i in range(0,38):
    end_score.append(z['api']['fixtures'][i]['score']['fulltime'])

# %%
end_score = pd.DataFrame(end_score)

# %%
end_score.to_csv('Raw_Data/getafe_stats_endscore.csv', sep= ',')

# %% [markdown]
# # Getafe new tables

# %%
x
# Out:
# 38

# %%
stats_list =[]
for i in range(0,38):
    stats_list.append(x[i]['api']['statistics'])
stats_list
# Out:
# [{'Shots on Goal': {'home': '2', 'away': '2'},
#   'Shots off Goal': {'home': '8', 'away': '4'},
#   'Total Shots': {'home': '13', 'away': '8'},
#   'Blocked Shots': {'home': '3', 'away': '2'},
#   'Shots insidebox': {'home': '10', 'away': '6'},
#   'Shots outsidebox': {'home': '3', 'away': '2'},
#   'Fouls': {'home': '16', 'away': '15'},
#   'Corner Kicks': {'home': '7', 'away': '6'},
#   'Offsides': {'home': '1', 'away': '1'},
#   'Ball Possession': {'home': '63%', 'away': '37%'},
#   'Yellow Cards': {'home': '1', 'away': '5'},
#   'Red Cards': {'home': '0', 'away': '1'},
#   'Goalkeeper Saves': {'home': '2', 'away': '2'},
#   'Total passes': {'home': '532', 'away': '303'},
#   'Passes accurate': {'home': '425', 'away': '189'},
#   'Passes %': {'home': '80%', 'away': '62%'}},
#  {'Shots on Goal': {'home': '3', 'away': '3'},
#   'Shots off Goal': {'home': '8', 'away': '3'},
#   'Total Shots': {'home': '15', 'away': '6'},
#   'Blocked Shots': {'home': '4', 'away': '0'},
# ...

# %%
stats_list[1]
# Out:
# {'Shots on Goal': {'home': '3', 'away': '3'},
#  'Shots off Goal': {'home': '8', 'away': '3'},
#  'Total Shots': {'home': '15', 'away': '6'},
#  'Blocked Shots': {'home': '4', 'away': '0'},
#  'Shots insidebox': {'home': '8', 'away': '5'},
#  'Shots outsidebox': {'home': '7', 'away': '1'},
#  'Fouls': {'home': '20', 'away': '10'},
#  'Corner Kicks': {'home': '7', 'away': '5'},
#  'Offsides': {'home': '3', 'away': '3'},
#  'Ball Possession': {'home': '43%', 'away': '57%'},
#  'Yellow Cards': {'home': '0', 'away': '1'},
#  'Red Cards': {'home': '0', 'away': '0'},
#  'Goalkeeper Saves': {'home': '2', 'away': '3'},
#  'Total passes': {'home': '356', 'away': '478'},
#  'Passes accurate': {'home': '234', 'away': '371'},
#  'Passes %': {'home': '66%', 'away': '78%'}}

# %%
super_list= []
for i in range(0,38):
    a,b = zip(*stats_list[i].items())
    a = list(a)
    b = list(b)
    super_list.append(b)

super_list
# Out:
# [[{'home': '2', 'away': '2'},
#   {'home': '8', 'away': '4'},
#   {'home': '13', 'away': '8'},
#   {'home': '3', 'away': '2'},
#   {'home': '10', 'away': '6'},
#   {'home': '3', 'away': '2'},
#   {'home': '16', 'away': '15'},
#   {'home': '7', 'away': '6'},
#   {'home': '1', 'away': '1'},
#   {'home': '63%', 'away': '37%'},
#   {'home': '1', 'away': '5'},
#   {'home': '0', 'away': '1'},
#   {'home': '2', 'away': '2'},
#   {'home': '532', 'away': '303'},
#   {'home': '425', 'away': '189'},
#   {'home': '80%', 'away': '62%'}],
#  [{'home': '3', 'away': '3'},
#   {'home': '8', 'away': '3'},
#   {'home': '15', 'away': '6'},
#   {'home': '4', 'away': '0'},
#   {'home': '8', 'away': '5'},
#   {'home': '7', 'away': '1'},
#   {'home': '20', 'away': '10'},
#   {'home': '7', 'away': '5'},
#   {'home': '3', 'away': '3'},
#   {'home': '43%', 'away': '57%'},
#   {'home': '0', 'away': '1'},
#   {'home': '0', 'away': '0'},
#   {'home': '2', 'away': '3'},
#   {'home': '356', 'away': '478'},
# ...

# %%
hometeam =pd.read_csv("Raw_data/getafe_stats_hometeam.csv", sep =',')
hometeam = hometeam[['team_id','team_name']]

# %%
home= []
for i in range(0,38):
    if hometeam['team_name'][i] == 'Getafe':
        home.append('Home')
    else:
        home.append('Away')
        
home
# Out:
# ['Away',
#  'Home',
#  'Away',
#  'Home',
#  'Away',
#  'Home',
#  'Away',
#  'Home',
#  'Away',
#  'Home',
#  'Away',
#  'Home',
#  'Away',
#  'Home',
#  'Home',
#  'Away',
#  'Home',
#  'Away',
#  'Home',
#  'Home',
#  'Away',
#  'Home',
#  'Away',
#  'Home',
#  'Away',
#  'Home',
#  'Away',
#  'Home',
#  'Away',
#  'Home',
#  'Away',
#  'Home',
#  'Away',
#  'Away',
#  'Home',
#  'Away',
#  'Home',
#  'Away']

# %%
clean_stats_getafe= []

for i in range(0,38):
    if home[i] == 'Home':
        for j in range(0,16):
            clean_stats_getafe.append(super_list[i][j]['home'])
    elif home[i] == 'Away':
        for k in range(0,16):
            clean_stats_getafe.append(super_list[i][k]['away'])
        
clean_stats_getafe
# Out:
# ['2',
#  '4',
#  '8',
#  '2',
#  '6',
#  '2',
#  '15',
#  '6',
#  '1',
#  '37%',
#  '5',
#  '1',
#  '2',
#  '303',
#  '189',
#  '62%',
#  '3',
#  '8',
#  '15',
#  '4',
#  '8',
#  '7',
#  '20',
#  '7',
#  '3',
#  '43%',
#  '0',
#  '0',
#  '2',
#  '356',
#  '234',
#  '66%',
#  '2',
#  '5',
#  '10',
#  '3',
#  '6',
#  '4',
#  '20',
#  '4',
#  '2',
#  '39%',
#  '2',
#  '0',
#  '6',
#  '285',
#  '166',
#  '58%',
#  '4',
#  '7',
#  '13',
#  '2',
#  '5',
#  '8',
#  '15',
#  '3',
#  '4',
#  '29%',
#  '2',
#  '0',
#  '3',
#  '272',
#  '187',
#  '69%',
#  '3',
#  '3',
#  '10',
#  '4',
#  '7',
#  '3',
#  '21',
#  '2',
#  '5',
#  '34%',
#  '4',
#  '0',
#  '3',
#  '280',
#  '184',
#  '66%',
#  '8',
#  '8',
#  '17',
#  '1',
#  '13',
#  '4',
#  '11',
#  '7',
#  '6',
#  '39%',
#  '1',
#  '0',
#  '1',
#  '292',
#  '198',
#  '68%',
#  '3',
#  '5',
#  '10',
#  '2',
#  '9',
#  '1',
#  '21',
#  '5',
#  '2',
#  '38%',
#  '3',
#  '0',
#  '7',
#  '266',
#  '151',
#  '57%',
#  '3',
#  '5',
#  '8',
#  '0',
# ...

# %%
for i in range(0, len(clean_stats_getafe), 16):
    chunk = clean_stats_getafe[i:i + 16]
    print(chunk)
# Out:
# ['2', '4', '8', '2', '6', '2', '15', '6', '1', '37%', '5', '1', '2', '303', '189', '62%']
# ['3', '8', '15', '4', '8', '7', '20', '7', '3', '43%', '0', '0', '2', '356', '234', '66%']
['1', '6', '10', '3', '3', '7', '13', '3', '3', '21%', '3', '0', '6', '203', '115', '57%'],
['5', '2', '9', '2', '6', '3', '21', '5', '1', '31%', '4', '0', '1', '254', '167', '66%'],
['3', '2', '5', '0', '2', '3', '21', '8', '5', '47%', '3', '0', '3', '357', '245', '69%'],
['5', '6', '14', '3', '8', '7', '6', '10', '2', '41%', '2', '0', '1', '310', '200', '65%'],
['4', '0', '4', '0', '2', '2', '18', '0', '4', '24%', '3', '1', '4', '258', '190', '74%'],
['3', '9', '13', '1', '10', '3', '14', '4', '2', '44%', '4', '0', '2', '278', '166', '60%'],
['5', '2', '9', '2', '6', '3', '21', '1', '4', '33%', '6', '0', '1', '236', '150', '64%'],
['4', '4', '8', '0', '7', '1', '21', '4', '4', '33%', '4', '0', '3', '271', '191', '70%'],
['1', '2', '5', '2', '3', '2', '22', '3', '3', '52%', '3', '0', '0', '344', '203', '59%'],
['4', '4', '13', '5', '8', '5', '19', '4', '4', '37%', '5', '1', '0', '280', '185', '66%'],
['3', '3', '8', '2', '3', '5', '14', '5', '3', '36%', '7', '0', '2', '301', '194', '64%'],
['4', '0', '7', '3', '5', '2', '16', '3', '1', '35%', '1', '0', '2', '234', '96', '41%'],
['2', '4', '10', '4', '7', '3', '19', '4', '1', '38%', '6', '1', '1', '261', '167', '64%'],
['1', '5', '8', '2', '6', '2', '28', '4', '3', '31%', '2', '0', '5', '212', '126', '59%'],
['4', '5', '11', '2', '7', '4', '13', '8', '0', '51%', '3', '0', '2', '410', '290', '71%'],
['3', '6', '11', '2', '6', '5', '12', '9', '3', '61%', '1', '0', '2', '441', '335', '76%']]

# %%
all_rows
# Out:
# [['2',
#   '4',
#   '8',
#   '2',
#   '6',
#   '2',
#   '15',
#   '6',
#   '1',
#   '37%',
#   '5',
#   '1',
#   '2',
#   '303',
#   '189',
#   '62%'],
#  ['3',
#   '8',
#   '15',
#   '4',
#   '8',
#   '7',
#   '20',
#   '7',
#   '3',
#   '43%',
#   '0',
#   '0',
#   '2',
#   '356',
#   '234',
#   '66%'],
#  ['2',
#   '5',
#   '10',
#   '3',
#   '6',
#   '4',
#   '20',
#   '4',
#   '2',
#   '39%',
#   '2',
#   '0',
#   '6',
#   '285',
#   '166',
#   '58%'],
#  ['4',
#   '7',
#   '13',
#   '2',
#   '5',
#   '8',
#   '15',
#   '3',
#   '4',
#   '29%',
#   '2',
#   '0',
#   '3',
#   '272',
#   '187',
#   '69%'],
#  ['3',
#   '3',
#   '10',
#   '4',
#   '7',
#   '3',
#   '21',
#   '2',
#   '5',
#   '34%',
#   '4',
#   '0',
#   '3',
#   '280',
#   '184',
#   '66%'],
#  ['8',
#   '8',
#   '17',
#   '1',
#   '13',
#   '4',
#   '11',
#   '7',
#   '6',
#   '39%',
#   '1',
#   '0',
#   '1',
#   '292',
#   '198',
#   '68%'],
#  ['3',
#   '5',
#   '10',
#   '2',
#   '9',
#   '1',
#   '21',
# ...

# %%
pd.DataFrame(data=all_rows, columns=['Shots on Goal','Shots off Goal',
 'Total Shots',
 'Blocked Shots' ,
 'Shots insidebox' ,
 'Shots outsidebox' ,
 'Fouls' ,
 'Corner Kicks' ,
 'Offsides' ,
 'Ball Possession' ,
 'Yellow Cards' ,
 'Red Cards' ,
 'Goalkeeper Saves' ,
 'Total passes' ,
 'Passes accurate',
 'Passes %'])
# Out:
#    Shots on Goal Shots off Goal Total Shots Blocked Shots Shots insidebox  \
# 0              2              4           8             2               6
# 1              3              8          15             4               8
# 2              2              5          10             3               6
# 3              4              7          13             2               5
# 4              3              3          10             4               7
# 5              8              8          17             1              13
# 6              3              5          10             2               9
# 7              3              5           8             0               5
# 8              5              2           9             2               6
# 9              5              2          10             3               7
# 10             2              6           9             1               8
# 11             8              2          13             3              11
# ...

# %%
getafe_stat_clean = pd.DataFrame(data=all_rows, columns=['Shots on Goal','Shots off Goal',
 'Total Shots',
 'Blocked Shots' ,
 'Shots insidebox' ,
 'Shots outsidebox' ,
 'Fouls' ,
 'Corner Kicks' ,
 'Offsides' ,
 'Ball Possession' ,
 'Yellow Cards' ,
 'Red Cards' ,
 'Goalkeeper Saves' ,
 'Total passes' ,
 'Passes accurate',
 'Passes %'])

# %%
getafe_stat_clean.to_csv("Raw_Data/getafe_stat_clean.csv", sep= ',')

# %% [markdown]
# # Endscore

# %%
getafe_stats_endscore = pd.read_csv("Raw_Data/getafe_stats_endscore.csv", sep=",", index_col= False)

# %%
getafe_stats_endscore = getafe_stats_endscore[['Unnamed: 0','0']]

# %%
getafe_stats_endscore = getafe_stats_endscore['0']

# %%
getafe_stats_endscore
# Out:
# 0     0-0
# 1     0-1
# 2     1-2
# 3     1-2
# 4     1-1
# 5     4-0
# 6     2-1
# 7     1-2
# 8     1-1
# 9     2-1
# 10    2-2
# 11    4-1
# 12    1-0
# 13    1-0
# 14    0-0
# 15    1-0
# 16    2-0
# 17    2-0
# 18    1-0
# 19    2-2
# 20    1-1
# 21    0-0
# 22    0-0
# 23    3-0
# 24    1-0
# 25    3-0
# 26    3-1
# 27    0-1
# 28    1-2
# 29    0-1
# 30    2-0
# 31    1-0
# 32    1-2
# 33    0-1
# 34    1-1
# 35    0-1
# 36    0-1
# 37    0-1
# Name: 0, dtype: object

# %% [markdown]
# # merge

# %%
first = pd.merge(getafe_stat_clean,getafe_stats_endscore, left_index=True, right_index= True)

# %%
home = pd.DataFrame(home)

# %%
final = pd.merge(home,first, left_index=True, right_index= True)

# %%
final
# Out:
#        0 Shots on Goal Shots off Goal Total Shots Blocked Shots  \
# 0   Away             2              4           8             2
# 1   Home             3              8          15             4
# 2   Away             2              5          10             3
# 3   Home             4              7          13             2
# 4   Away             3              3          10             4
# 5   Home             8              8          17             1
# 6   Away             3              5          10             2
# 7   Home             3              5           8             0
# 8   Away             5              2           9             2
# 9   Home             5              2          10             3
# 10  Away             2              6           9             1
# 11  Home             8              2          13             3
# 12  Away             4              3           7          None
# 13  Home             3              3          11             5
# ...

# %%
final.to_csv("Raw_Data/getafe_final_clean.csv", sep=',')
