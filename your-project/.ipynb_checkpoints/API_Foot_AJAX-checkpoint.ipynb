# %%
import requests
import json
import pandas as pd
import getpass

# %%
# Get Team_ID\ AJAX 194
url = "https://v2.api-football.com/teams/league/10"

payload = {}
headers = {
  'x-rapidapi-key': '85fcf85753adf7519cc4f7b7535edf10'
}

response = requests.request("GET", url, headers=headers, data = payload)

print(response.text.encode('utf8'))
# Out:
# b'{"api":{"results":18,"teams":[{"team_id":193,"name":"PEC Zwolle","code":null,"logo":"https:\\/\\/media.api-sports.io\\/football\\/teams\\/193.png","country":"Netherlands","is_national":false,"founded":1990,"venue_name":"MAC\\u00b3PARK Stadion","venue_surface":"artificial turf","venue_address":"Stadionplein 1","venue_city":"Zwolle","venue_capacity":14000},{"team_id":210,"name":"Heerenveen","code":null,"logo":"https:\\/\\/media.api-sports.io\\/football\\/teams\\/210.png","country":"Netherlands","is_national":false,"founded":1920,"venue_name":"Abe Lenstra Stadion","venue_surface":"grass","venue_address":"Abe Lenstra Boulevard 23Q","venue_city":"Heerenveen","venue_capacity":27224},{"team_id":194,"name":"Ajax","code":null,"logo":"https:\\/\\/media.api-sports.io\\/football\\/teams\\/194.png","country":"Netherlands","is_national":false,"founded":1900,"venue_name":"Johan Cruijff Arena","venue_surface":"grass","venue_address":"ArenA Boulevard 1","venue_city":"Amsterdam","venue_capacity":549
# ...

# %%
teams = response.json()
teams
# Out:
# {'api': {'results': 18,
#   'teams': [{'team_id': 193,
#     'name': 'PEC Zwolle',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/193.png',
#     'country': 'Netherlands',
#     'is_national': False,
#     'founded': 1990,
#     'venue_name': 'MAC³PARK Stadion',
#     'venue_surface': 'artificial turf',
#     'venue_address': 'Stadionplein 1',
#     'venue_city': 'Zwolle',
#     'venue_capacity': 14000},
#    {'team_id': 210,
#     'name': 'Heerenveen',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/210.png',
#     'country': 'Netherlands',
#     'is_national': False,
#     'founded': 1920,
#     'venue_name': 'Abe Lenstra Stadion',
#     'venue_surface': 'grass',
#     'venue_address': 'Abe Lenstra Boulevard 23Q',
#     'venue_city': 'Heerenveen',
#     'venue_capacity': 27224},
#    {'team_id': 194,
#     'name': 'Ajax',
#     'code': None,
#     'logo': 'https://media.api-sports.io/football/teams/194.png',
# ...

# %% [markdown]
# # AJAX statistics overall

# %%
url = "https://v2.api-football.com/statistics/10/194"

payload = {}
headers = {
  'x-rapidapi-key': '85fcf85753adf7519cc4f7b7535edf10'
}

response = requests.request("GET", url, headers=headers, data = payload)

print(response.text.encode('utf8'))
# Out:
# b'{"api":{"results":1,"statistics":{"matchs":{"matchsPlayed":{"home":17,"away":17,"total":34},"wins":{"home":15,"away":13,"total":28},"draws":{"home":2,"away":0,"total":2},"loses":{"home":0,"away":4,"total":4}},"goals":{"goalsFor":{"home":70,"away":49,"total":119},"goalsAgainst":{"home":13,"away":19,"total":32}},"goalsAvg":{"goalsFor":{"home":"4.1","away":"2.9","total":"3.5"},"goalsAgainst":{"home":"0.8","away":"1.1","total":"0.9"}}}}}'

# %%
overall_ajax = response.json()
overall_ajax
# Out:
# {'api': {'results': 1,
#   'statistics': {'matchs': {'matchsPlayed': {'home': 17,
#      'away': 17,
#      'total': 34},
#     'wins': {'home': 15, 'away': 13, 'total': 28},
#     'draws': {'home': 2, 'away': 0, 'total': 2},
#     'loses': {'home': 0, 'away': 4, 'total': 4}},
#    'goals': {'goalsFor': {'home': 70, 'away': 49, 'total': 119},
#     'goalsAgainst': {'home': 13, 'away': 19, 'total': 32}},
#    'goalsAvg': {'goalsFor': {'home': '4.1', 'away': '2.9', 'total': '3.5'},
#     'goalsAgainst': {'home': '0.8', 'away': '1.1', 'total': '0.9'}}}}}

# %% [markdown]
# # Get Fixtures_ID

# %%
url = "https://v2.api-football.com/fixtures/team/194/10"

payload = {}
headers = {
  'x-rapidapi-key': '85fcf85753adf7519cc4f7b7535edf10'
}

response = requests.request("GET", url, headers=headers, data = payload)

print(response.text.encode('utf8'))
# Out:
# b'{"api":{"results":34,"fixtures":[{"fixture_id":3129,"league_id":10,"league":{"name":"Eredivisie","country":"Netherlands","logo":"https:\\/\\/media.api-sports.io\\/football\\/leagues\\/88.png","flag":"https:\\/\\/media.api-sports.io\\/flags\\/nl.svg"},"event_date":"2018-08-11T16:30:00+00:00","event_timestamp":1534005000,"firstHalfStart":1534005000,"secondHalfStart":1534008600,"round":"Regular Season - 1","status":"Match Finished","statusShort":"FT","elapsed":90,"venue":"Johan Cruijff Arena","referee":"Serdar Gozubuyuk, Netherlands","homeTeam":{"team_id":194,"team_name":"Ajax","logo":"https:\\/\\/media.api-sports.io\\/football\\/teams\\/194.png"},"awayTeam":{"team_id":206,"team_name":"Heracles","logo":"https:\\/\\/media.api-sports.io\\/football\\/teams\\/206.png"},"goalsHomeTeam":1,"goalsAwayTeam":1,"score":{"halftime":"0-0","fulltime":"1-1","extratime":null,"penalty":null}},{"fixture_id":3139,"league_id":10,"league":{"name":"Eredivisie","country":"Netherlands","logo":"https:\\/\\/me
# ...

# %%
fixtures_ajax_all = response.json()
fixtures_ajax_all
# Out:
# {'api': {'results': 34,
#   'fixtures': [{'fixture_id': 3129,
#     'league_id': 10,
#     'league': {'name': 'Eredivisie',
#      'country': 'Netherlands',
#      'logo': 'https://media.api-sports.io/football/leagues/88.png',
#      'flag': 'https://media.api-sports.io/flags/nl.svg'},
#     'event_date': '2018-08-11T16:30:00+00:00',
#     'event_timestamp': 1534005000,
#     'firstHalfStart': 1534005000,
#     'secondHalfStart': 1534008600,
#     'round': 'Regular Season - 1',
#     'status': 'Match Finished',
#     'statusShort': 'FT',
#     'elapsed': 90,
#     'venue': 'Johan Cruijff Arena',
#     'referee': 'Serdar Gozubuyuk, Netherlands',
#     'homeTeam': {'team_id': 194,
#      'team_name': 'Ajax',
#      'logo': 'https://media.api-sports.io/football/teams/194.png'},
#     'awayTeam': {'team_id': 206,
#      'team_name': 'Heracles',
#      'logo': 'https://media.api-sports.io/football/teams/206.png'},
#     'goalsHomeTeam': 1,
#     'goalsAwayTeam': 1,
# ...

# %%
# From result_get, we want to extract all ficxture_id 's/matches in La Liga
# List of  dict, all 38 fixtures

fixtures_ajax= []
fixtures_aja_home = []
for game in range(0,34):
    fixtures_ajax.append(fixtures_ajax_all['api']['fixtures'][game]['fixture_id'])
    fixtures_aja_home.append(fixtures_ajax_all['api']['fixtures'][game]['homeTeam'])

print(len(fixtures_ajax))
fixtures_aja_home
# Out:
# 34
# [{'team_id': 194,
#   'team_name': 'Ajax',
#   'logo': 'https://media.api-sports.io/football/teams/194.png'},
#  {'team_id': 204,
#   'team_name': 'VVV Venlo',
#   'logo': 'https://media.api-sports.io/football/teams/204.png'},
#  {'team_id': 194,
#   'team_name': 'Ajax',
#   'logo': 'https://media.api-sports.io/football/teams/194.png'},
#  {'team_id': 200,
#   'team_name': 'Vitesse',
#   'logo': 'https://media.api-sports.io/football/teams/200.png'},
#  {'team_id': 194,
#   'team_name': 'Ajax',
#   'logo': 'https://media.api-sports.io/football/teams/194.png'},
#  {'team_id': 197,
#   'team_name': 'PSV Eindhoven',
#   'logo': 'https://media.api-sports.io/football/teams/197.png'},
#  {'team_id': 205,
#   'team_name': 'Fortuna Sittard',
#   'logo': 'https://media.api-sports.io/football/teams/205.png'},
#  {'team_id': 194,
#   'team_name': 'Ajax',
#   'logo': 'https://media.api-sports.io/football/teams/194.png'},
#  {'team_id': 210,
#   'team_name': 'Heerenveen',
# ...

# %%
full_response= []


for fixture in range(0,34):
    url = "https://v2.api-football.com/statistics/fixture/" +str(fixtures_ajax[fixture])

    payload = {}
    headers = {
      'x-rapidapi-key': '85fcf85753adf7519cc4f7b7535edf10'
    }

    response = requests.request("GET", url, headers=headers, data = payload).json()
    
    # Add dict of the response in our full_response list
    full_response.append(response)

# %%
full_response[33]
# Out:
# {'api': {'results': 16,
#   'statistics': {'Shots on Goal': {'home': '3', 'away': '9'},
#    'Shots off Goal': {'home': '5', 'away': '2'},
#    'Total Shots': {'home': '11', 'away': '16'},
#    'Blocked Shots': {'home': '3', 'away': '5'},
#    'Shots insidebox': {'home': '6', 'away': '10'},
#    'Shots outsidebox': {'home': '5', 'away': '6'},
#    'Fouls': {'home': '8', 'away': '6'},
#    'Corner Kicks': {'home': '2', 'away': '6'},
#    'Offsides': {'home': '0', 'away': '3'},
#    'Ball Possession': {'home': '37%', 'away': '63%'},
#    'Yellow Cards': {'home': '1', 'away': '0'},
#    'Red Cards': {'home': None, 'away': None},
#    'Goalkeeper Saves': {'home': '5', 'away': '2'},
#    'Total passes': {'home': '329', 'away': '558'},
#    'Passes accurate': {'home': '240', 'away': '478'},
#    'Passes %': {'home': '73%', 'away': '86%'}}}}

# %%
len(full_response)
# Out:
# 34

# %%
x = pd.DataFrame(full_response)

# %%
full_response[1]['api']['statistics']
# Out:
# {'Shots on Goal': {'home': '1', 'away': '9'},
#  'Shots off Goal': {'home': '5', 'away': '8'},
#  'Total Shots': {'home': '9', 'away': '18'},
#  'Blocked Shots': {'home': '3', 'away': '1'},
#  'Shots insidebox': {'home': '4', 'away': '10'},
#  'Shots outsidebox': {'home': '5', 'away': '8'},
#  'Fouls': {'home': '8', 'away': '9'},
#  'Corner Kicks': {'home': '5', 'away': '7'},
#  'Offsides': {'home': '0', 'away': '2'},
#  'Ball Possession': {'home': '27%', 'away': '73%'},
#  'Yellow Cards': {'home': '0', 'away': '1'},
#  'Red Cards': {'home': '0', 'away': '0'},
#  'Goalkeeper Saves': {'home': '8', 'away': '1'},
#  'Total passes': {'home': '252', 'away': '666'},
#  'Passes accurate': {'home': '166', 'away': '591'},
#  'Passes %': {'home': '66%', 'away': '89%'}}

# %%
data = []
for i in range(0,34):
    data.append(full_response[i]['api']['statistics'])
    
data
# Out:
# [{'Shots on Goal': {'home': '7', 'away': '2'},
#   'Shots off Goal': {'home': '6', 'away': '6'},
#   'Total Shots': {'home': '17', 'away': '11'},
#   'Blocked Shots': {'home': '4', 'away': '3'},
#   'Shots insidebox': {'home': '9', 'away': '5'},
#   'Shots outsidebox': {'home': '8', 'away': '6'},
#   'Fouls': {'home': '13', 'away': '25'},
#   'Corner Kicks': {'home': '12', 'away': '7'},
#   'Offsides': {'home': None, 'away': None},
#   'Ball Possession': {'home': '65%', 'away': '35%'},
#   'Yellow Cards': {'home': '0', 'away': '4'},
#   'Red Cards': {'home': '0', 'away': '0'},
#   'Goalkeeper Saves': {'home': '1', 'away': '7'},
#   'Total passes': {'home': '547', 'away': '291'},
#   'Passes accurate': {'home': '453', 'away': '203'},
#   'Passes %': {'home': '83%', 'away': '70%'}},
#  {'Shots on Goal': {'home': '1', 'away': '9'},
#   'Shots off Goal': {'home': '5', 'away': '8'},
#   'Total Shots': {'home': '9', 'away': '18'},
#   'Blocked Shots': {'home': '3', 'away': '1'},
# ...

# %%
raw_data = pd.DataFrame(data)
raw_data.to_csv('Raw_Data/ajax_stats_ha.csv', sep= ',')

# %%
y = [{'team_id': 194,
  'team_name': 'Ajax',
  'logo': 'https://media.api-sports.io/football/teams/194.png'},
 {'team_id': 204,
  'team_name': 'VVV Venlo',
  'logo': 'https://media.api-sports.io/football/teams/204.png'},
 {'team_id': 194,
  'team_name': 'Ajax',
  'logo': 'https://media.api-sports.io/football/teams/194.png'},
 {'team_id': 200,
  'team_name': 'Vitesse',
  'logo': 'https://media.api-sports.io/football/teams/200.png'},
 {'team_id': 194,
  'team_name': 'Ajax',
  'logo': 'https://media.api-sports.io/football/teams/194.png'},
 {'team_id': 197,
  'team_name': 'PSV Eindhoven',
  'logo': 'https://media.api-sports.io/football/teams/197.png'},
 {'team_id': 205,
  'team_name': 'Fortuna Sittard',
  'logo': 'https://media.api-sports.io/football/teams/205.png'},
 {'team_id': 194,
  'team_name': 'Ajax',
  'logo': 'https://media.api-sports.io/football/teams/194.png'},
 {'team_id': 210,
  'team_name': 'Heerenveen',
  'logo': 'https://media.api-sports.io/football/teams/210.png'},
 {'team_id': 194,
  'team_name': 'Ajax',
  'logo': 'https://media.api-sports.io/football/teams/194.png'},
 {'team_id': 194,
  'team_name': 'Ajax',
  'logo': 'https://media.api-sports.io/football/teams/194.png'},
 {'team_id': 196,
  'team_name': 'Excelsior',
  'logo': 'https://media.api-sports.io/football/teams/196.png'},
 {'team_id': 203,
  'team_name': 'NAC Breda',
  'logo': 'https://media.api-sports.io/football/teams/203.png'},
 {'team_id': 194,
  'team_name': 'Ajax',
  'logo': 'https://media.api-sports.io/football/teams/194.png'},
 {'team_id': 193,
  'team_name': 'PEC Zwolle',
  'logo': 'https://media.api-sports.io/football/teams/193.png'},
 {'team_id': 194,
  'team_name': 'Ajax',
  'logo': 'https://media.api-sports.io/football/teams/194.png'},
 {'team_id': 207,
  'team_name': 'Utrecht',
  'logo': 'https://media.api-sports.io/football/teams/207.png'},
 {'team_id': 194,
  'team_name': 'Ajax',
  'logo': 'https://media.api-sports.io/football/teams/194.png'},
 {'team_id': 209,
  'team_name': 'Feyenoord',
  'logo': 'https://media.api-sports.io/football/teams/209.png'},
 {'team_id': 194,
  'team_name': 'Ajax',
  'logo': 'https://media.api-sports.io/football/teams/194.png'},
 {'team_id': 206,
  'team_name': 'Heracles',
  'logo': 'https://media.api-sports.io/football/teams/206.png'},
 {'team_id': 194,
  'team_name': 'Ajax',
  'logo': 'https://media.api-sports.io/football/teams/194.png'},
 {'team_id': 198,
  'team_name': 'ADO Den Haag',
  'logo': 'https://media.api-sports.io/football/teams/198.png'},
 {'team_id': 194,
  'team_name': 'Ajax',
  'logo': 'https://media.api-sports.io/football/teams/194.png'},
 {'team_id': 194,
  'team_name': 'Ajax',
  'logo': 'https://media.api-sports.io/football/teams/194.png'},
 {'team_id': 201,
  'team_name': 'AZ Alkmaar',
  'logo': 'https://media.api-sports.io/football/teams/201.png'},
 {'team_id': 194,
  'team_name': 'Ajax',
  'logo': 'https://media.api-sports.io/football/teams/194.png'},
 {'team_id': 208,
  'team_name': 'Emmen',
  'logo': 'https://media.api-sports.io/football/teams/208.png'},
 {'team_id': 195,
  'team_name': 'Willem II',
  'logo': 'https://media.api-sports.io/football/teams/195.png'},
 {'team_id': 194,
  'team_name': 'Ajax',
  'logo': 'https://media.api-sports.io/football/teams/194.png'},
 {'team_id': 202,
  'team_name': 'Groningen',
  'logo': 'https://media.api-sports.io/football/teams/202.png'},
 {'team_id': 194,
  'team_name': 'Ajax',
  'logo': 'https://media.api-sports.io/football/teams/194.png'},
 {'team_id': 194,
  'team_name': 'Ajax',
  'logo': 'https://media.api-sports.io/football/teams/194.png'},
 {'team_id': 199,
  'team_name': 'De Graafschap',
  'logo': 'https://media.api-sports.io/football/teams/199.png'}]

# %%
raw_hometeam = pd.DataFrame(y)

# %%
raw_hometeam.to_csv('Raw_Data/ajax_stats_hometeam.csv', sep= ',')

# %%
overall = {'api': {'results': 1,
  'statistics': {'matchs': {'matchsPlayed': {'home': 17,
     'away': 17,
     'total': 34},
    'wins': {'home': 15, 'away': 13, 'total': 28},
    'draws': {'home': 2, 'away': 0, 'total': 2},
    'loses': {'home': 0, 'away': 4, 'total': 4}},
   'goals': {'goalsFor': {'home': 70, 'away': 49, 'total': 119},
    'goalsAgainst': {'home': 13, 'away': 19, 'total': 32}},
   'goalsAvg': {'goalsFor': {'home': '4.1', 'away': '2.9', 'total': '3.5'},
    'goalsAgainst': {'home': '0.8', 'away': '1.1', 'total': '0.9'}}}}}

# %%
overall = overall['api']['statistics']
overall = pd.DataFrame(overall)

# %%
overall.to_csv('Raw_Data/ajax_stats_overall.csv', sep= ',')

# %%
z = {'api': {'results': 34,
  'fixtures': [{'fixture_id': 3129,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2018-08-11T16:30:00+00:00',
    'event_timestamp': 1534005000,
    'firstHalfStart': 1534005000,
    'secondHalfStart': 1534008600,
    'round': 'Regular Season - 1',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Johan Cruijff Arena',
    'referee': 'Serdar Gozubuyuk, Netherlands',
    'homeTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'awayTeam': {'team_id': 206,
     'team_name': 'Heracles',
     'logo': 'https://media.api-sports.io/football/teams/206.png'},
    'goalsHomeTeam': 1,
    'goalsAwayTeam': 1,
    'score': {'halftime': '0-0',
     'fulltime': '1-1',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3139,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2018-08-18T16:30:00+00:00',
    'event_timestamp': 1534609800,
    'firstHalfStart': 1534609800,
    'secondHalfStart': 1534613400,
    'round': 'Regular Season - 2',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Seacon Stadion De Koel',
    'referee': 'Kevin Blom, Netherlands',
    'homeTeam': {'team_id': 204,
     'team_name': 'VVV Venlo',
     'logo': 'https://media.api-sports.io/football/teams/204.png'},
    'awayTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'goalsHomeTeam': 0,
    'goalsAwayTeam': 1,
    'score': {'halftime': '0-0',
     'fulltime': '0-1',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3147,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2018-08-25T16:30:00+00:00',
    'event_timestamp': 1535214600,
    'firstHalfStart': 1535214600,
    'secondHalfStart': 1535218200,
    'round': 'Regular Season - 3',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Johan Cruijff Arena',
    'referee': 'Bas Nijhuis, Netherlands',
    'homeTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'awayTeam': {'team_id': 208,
     'team_name': 'Emmen',
     'logo': 'https://media.api-sports.io/football/teams/208.png'},
    'goalsHomeTeam': 5,
    'goalsAwayTeam': 0,
    'score': {'halftime': '2-0',
     'fulltime': '5-0',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3162,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2018-09-02T12:30:00+00:00',
    'event_timestamp': 1535891400,
    'firstHalfStart': 1535891400,
    'secondHalfStart': 1535895000,
    'round': 'Regular Season - 4',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'GelreDome',
    'referee': 'Pol van Boekel, Netherlands',
    'homeTeam': {'team_id': 200,
     'team_name': 'Vitesse',
     'logo': 'https://media.api-sports.io/football/teams/200.png'},
    'awayTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'goalsHomeTeam': 0,
    'goalsAwayTeam': 4,
    'score': {'halftime': '0-3',
     'fulltime': '0-4',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3166,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2018-09-15T18:45:00+00:00',
    'event_timestamp': 1537037100,
    'firstHalfStart': 1537037100,
    'secondHalfStart': 1537040700,
    'round': 'Regular Season - 5',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Johan Cruijff Arena',
    'referee': 'Dennis Higler, Netherlands',
    'homeTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'awayTeam': {'team_id': 202,
     'team_name': 'Groningen',
     'logo': 'https://media.api-sports.io/football/teams/202.png'},
    'goalsHomeTeam': 3,
    'goalsAwayTeam': 0,
    'score': {'halftime': '1-0',
     'fulltime': '3-0',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3181,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2018-09-23T14:45:00+00:00',
    'event_timestamp': 1537713900,
    'firstHalfStart': 1537713900,
    'secondHalfStart': 1537717500,
    'round': 'Regular Season - 6',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Philips Stadion',
    'referee': 'Danny Desmond Makkelie, Netherlands',
    'homeTeam': {'team_id': 197,
     'team_name': 'PSV Eindhoven',
     'logo': 'https://media.api-sports.io/football/teams/197.png'},
    'awayTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'goalsHomeTeam': 3,
    'goalsAwayTeam': 0,
    'score': {'halftime': '3-0',
     'fulltime': '3-0',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3185,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2018-09-29T18:45:00+00:00',
    'event_timestamp': 1538246700,
    'firstHalfStart': 1538246700,
    'secondHalfStart': 1538250300,
    'round': 'Regular Season - 7',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Fortuna Sittard Stadion',
    'referee': 'Pol van Boekel, Netherlands',
    'homeTeam': {'team_id': 205,
     'team_name': 'Fortuna Sittard',
     'logo': 'https://media.api-sports.io/football/teams/205.png'},
    'awayTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'goalsHomeTeam': 0,
    'goalsAwayTeam': 2,
    'score': {'halftime': '0-0',
     'fulltime': '0-2',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3199,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2018-10-07T14:45:00+00:00',
    'event_timestamp': 1538923500,
    'firstHalfStart': 1538923500,
    'secondHalfStart': 1538927100,
    'round': 'Regular Season - 8',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Johan Cruijff Arena',
    'referee': 'Dennis Higler, Netherlands',
    'homeTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'awayTeam': {'team_id': 201,
     'team_name': 'AZ Alkmaar',
     'logo': 'https://media.api-sports.io/football/teams/201.png'},
    'goalsHomeTeam': 5,
    'goalsAwayTeam': 0,
    'score': {'halftime': '1-0',
     'fulltime': '5-0',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3202,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2018-10-20T18:45:00+00:00',
    'event_timestamp': 1540061100,
    'firstHalfStart': 1540061100,
    'secondHalfStart': 1540064700,
    'round': 'Regular Season - 9',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Abe Lenstra Stadion',
    'referee': 'Pol van Boekel, Netherlands',
    'homeTeam': {'team_id': 210,
     'team_name': 'Heerenveen',
     'logo': 'https://media.api-sports.io/football/teams/210.png'},
    'awayTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'goalsHomeTeam': 0,
    'goalsAwayTeam': 4,
    'score': {'halftime': '0-2',
     'fulltime': '0-4',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3215,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2018-10-28T13:30:00+00:00',
    'event_timestamp': 1540733400,
    'firstHalfStart': 1540733400,
    'secondHalfStart': 1540737000,
    'round': 'Regular Season - 10',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Johan Cruijff Arena',
    'referee': 'Bjorn Kuipers, Netherlands',
    'homeTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'awayTeam': {'team_id': 209,
     'team_name': 'Feyenoord',
     'logo': 'https://media.api-sports.io/football/teams/209.png'},
    'goalsHomeTeam': 3,
    'goalsAwayTeam': 0,
    'score': {'halftime': '2-0',
     'fulltime': '3-0',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3219,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2018-11-03T19:45:00+00:00',
    'event_timestamp': 1541274300,
    'firstHalfStart': 1541274300,
    'secondHalfStart': 1541277900,
    'round': 'Regular Season - 11',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Johan Cruijff Arena',
    'referee': 'Allard Lindhout, Netherlands',
    'homeTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'awayTeam': {'team_id': 195,
     'team_name': 'Willem II',
     'logo': 'https://media.api-sports.io/football/teams/195.png'},
    'goalsHomeTeam': 2,
    'goalsAwayTeam': 0,
    'score': {'halftime': '2-0',
     'fulltime': '2-0',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3234,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2018-11-11T13:30:00+00:00',
    'event_timestamp': 1541943000,
    'firstHalfStart': 1541943000,
    'secondHalfStart': 1541946600,
    'round': 'Regular Season - 12',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Stadion Woudestein',
    'referee': 'Serdar Gozubuyuk, Netherlands',
    'homeTeam': {'team_id': 196,
     'team_name': 'Excelsior',
     'logo': 'https://media.api-sports.io/football/teams/196.png'},
    'awayTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'goalsHomeTeam': 1,
    'goalsAwayTeam': 7,
    'score': {'halftime': '0-2',
     'fulltime': '1-7',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3239,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2018-11-24T17:30:00+00:00',
    'event_timestamp': 1543080600,
    'firstHalfStart': 1543080600,
    'secondHalfStart': 1543084200,
    'round': 'Regular Season - 13',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Rat Verlegh Stadion',
    'referee': 'Dennis Higler, Netherlands',
    'homeTeam': {'team_id': 203,
     'team_name': 'NAC Breda',
     'logo': 'https://media.api-sports.io/football/teams/203.png'},
    'awayTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'goalsHomeTeam': 0,
    'goalsAwayTeam': 3,
    'score': {'halftime': '0-1',
     'fulltime': '0-3',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3250,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2018-12-02T11:15:00+00:00',
    'event_timestamp': 1543749300,
    'firstHalfStart': 1543749300,
    'secondHalfStart': 1543752900,
    'round': 'Regular Season - 14',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Johan Cruijff Arena',
    'referee': 'Pol van Boekel, Netherlands',
    'homeTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'awayTeam': {'team_id': 198,
     'team_name': 'ADO Den Haag',
     'logo': 'https://media.api-sports.io/football/teams/198.png'},
    'goalsHomeTeam': 5,
    'goalsAwayTeam': 1,
    'score': {'halftime': '3-1',
     'fulltime': '5-1',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3258,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2018-12-08T18:45:00+00:00',
    'event_timestamp': 1544294700,
    'firstHalfStart': 1544294700,
    'secondHalfStart': 1544298300,
    'round': 'Regular Season - 15',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Mac3Park Stadion',
    'referee': 'Jochem Kamphuis, Netherlands',
    'homeTeam': {'team_id': 193,
     'team_name': 'PEC Zwolle',
     'logo': 'https://media.api-sports.io/football/teams/193.png'},
    'awayTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'goalsHomeTeam': 1,
    'goalsAwayTeam': 4,
    'score': {'halftime': '1-2',
     'fulltime': '1-4',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3269,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2018-12-16T13:30:00+00:00',
    'event_timestamp': 1544967000,
    'firstHalfStart': 1544967000,
    'secondHalfStart': 1544970600,
    'round': 'Regular Season - 16',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Johan Cruijff Arena',
    'referee': 'Bernie Raymond Blom, Netherlands',
    'homeTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'awayTeam': {'team_id': 199,
     'team_name': 'De Graafschap',
     'logo': 'https://media.api-sports.io/football/teams/199.png'},
    'goalsHomeTeam': 8,
    'goalsAwayTeam': 0,
    'score': {'halftime': '3-0',
     'fulltime': '8-0',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3277,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2018-12-23T11:15:00+00:00',
    'event_timestamp': 1545563700,
    'firstHalfStart': 1545563700,
    'secondHalfStart': 1545567300,
    'round': 'Regular Season - 17',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Stadion Galgenwaard',
    'referee': 'Dennis Higler, Netherlands',
    'homeTeam': {'team_id': 207,
     'team_name': 'Utrecht',
     'logo': 'https://media.api-sports.io/football/teams/207.png'},
    'awayTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'goalsHomeTeam': 1,
    'goalsAwayTeam': 3,
    'score': {'halftime': '0-1',
     'fulltime': '1-3',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3289,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2019-01-20T15:45:00+00:00',
    'event_timestamp': 1547999100,
    'firstHalfStart': 1547999100,
    'secondHalfStart': 1548002700,
    'round': 'Regular Season - 18',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Johan Cruijff Arena',
    'referee': 'Serdar Gozubuyuk, Netherlands',
    'homeTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'awayTeam': {'team_id': 210,
     'team_name': 'Heerenveen',
     'logo': 'https://media.api-sports.io/football/teams/210.png'},
    'goalsHomeTeam': 4,
    'goalsAwayTeam': 4,
    'score': {'halftime': '3-1',
     'fulltime': '4-4',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3296,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2019-01-27T13:30:00+00:00',
    'event_timestamp': 1548595800,
    'firstHalfStart': 1548595800,
    'secondHalfStart': 1548599400,
    'round': 'Regular Season - 19',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'De Kuip',
    'referee': 'Danny Desmond Makkelie, Netherlands',
    'homeTeam': {'team_id': 209,
     'team_name': 'Feyenoord',
     'logo': 'https://media.api-sports.io/football/teams/209.png'},
    'awayTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'goalsHomeTeam': 6,
    'goalsAwayTeam': 2,
    'score': {'halftime': '3-2',
     'fulltime': '6-2',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3301,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2019-02-02T18:45:00+00:00',
    'event_timestamp': 1549133100,
    'firstHalfStart': 1549133100,
    'secondHalfStart': 1549136700,
    'round': 'Regular Season - 20',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Johan Cruijff Arena',
    'referee': 'Allard Lindhout, Netherlands',
    'homeTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'awayTeam': {'team_id': 204,
     'team_name': 'VVV Venlo',
     'logo': 'https://media.api-sports.io/football/teams/204.png'},
    'goalsHomeTeam': 6,
    'goalsAwayTeam': 0,
    'score': {'halftime': '1-0',
     'fulltime': '6-0',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3310,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2019-02-09T17:30:00+00:00',
    'event_timestamp': 1549733400,
    'firstHalfStart': 1549733400,
    'secondHalfStart': 1549737000,
    'round': 'Regular Season - 21',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Polman Stadion',
    'referee': 'Dennis Higler, Netherlands',
    'homeTeam': {'team_id': 206,
     'team_name': 'Heracles',
     'logo': 'https://media.api-sports.io/football/teams/206.png'},
    'awayTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'goalsHomeTeam': 1,
    'goalsAwayTeam': 0,
    'score': {'halftime': '1-0',
     'fulltime': '1-0',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3322,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2019-02-17T11:15:00+00:00',
    'event_timestamp': 1550402100,
    'firstHalfStart': 1550402100,
    'secondHalfStart': 1550405700,
    'round': 'Regular Season - 22',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Johan Cruijff Arena',
    'referee': 'Siemen Mulder, Netherlands',
    'homeTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'awayTeam': {'team_id': 203,
     'team_name': 'NAC Breda',
     'logo': 'https://media.api-sports.io/football/teams/203.png'},
    'goalsHomeTeam': 5,
    'goalsAwayTeam': 0,
    'score': {'halftime': '1-0',
     'fulltime': '5-0',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3331,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2019-02-24T11:15:00+00:00',
    'event_timestamp': 1551006900,
    'firstHalfStart': 1551006900,
    'secondHalfStart': 1551010500,
    'round': 'Regular Season - 23',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Cars Jeans Stadion',
    'referee': 'Jeroen Manschot, Netherlands',
    'homeTeam': {'team_id': 198,
     'team_name': 'ADO Den Haag',
     'logo': 'https://media.api-sports.io/football/teams/198.png'},
    'awayTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'goalsHomeTeam': 1,
    'goalsAwayTeam': 5,
    'score': {'halftime': '1-2',
     'fulltime': '1-5',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3352,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2019-03-10T15:45:00+00:00',
    'event_timestamp': 1552232700,
    'firstHalfStart': 1552232700,
    'secondHalfStart': 1552236300,
    'round': 'Regular Season - 25',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Johan Cruijff Arena',
    'referee': 'Jochem Kamphuis, Netherlands',
    'homeTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'awayTeam': {'team_id': 205,
     'team_name': 'Fortuna Sittard',
     'logo': 'https://media.api-sports.io/football/teams/205.png'},
    'goalsHomeTeam': 4,
    'goalsAwayTeam': 0,
    'score': {'halftime': '2-0',
     'fulltime': '4-0',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3341,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2019-03-13T17:30:00+00:00',
    'event_timestamp': 1552498200,
    'firstHalfStart': 1552498200,
    'secondHalfStart': 1552501800,
    'round': 'Regular Season - 24',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Johan Cruijff Arena',
    'referee': 'Allard Lindhout, Netherlands',
    'homeTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'awayTeam': {'team_id': 193,
     'team_name': 'PEC Zwolle',
     'logo': 'https://media.api-sports.io/football/teams/193.png'},
    'goalsHomeTeam': 2,
    'goalsAwayTeam': 1,
    'score': {'halftime': '1-0',
     'fulltime': '2-1',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3359,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2019-03-17T13:30:00+00:00',
    'event_timestamp': 1552829400,
    'firstHalfStart': 1552829400,
    'secondHalfStart': 1552833000,
    'round': 'Regular Season - 26',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'AFAS Stadion',
    'referee': 'Serdar Gozubuyuk, Netherlands',
    'homeTeam': {'team_id': 201,
     'team_name': 'AZ Alkmaar',
     'logo': 'https://media.api-sports.io/football/teams/201.png'},
    'awayTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'goalsHomeTeam': 1,
    'goalsAwayTeam': 0,
    'score': {'halftime': '0-0',
     'fulltime': '1-0',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3370,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2019-03-31T14:45:00+00:00',
    'event_timestamp': 1554043500,
    'firstHalfStart': 1554043500,
    'secondHalfStart': 1554047100,
    'round': 'Regular Season - 27',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Johan Cruijff Arena',
    'referee': 'Bjorn Kuipers, Netherlands',
    'homeTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'awayTeam': {'team_id': 197,
     'team_name': 'PSV Eindhoven',
     'logo': 'https://media.api-sports.io/football/teams/197.png'},
    'goalsHomeTeam': 3,
    'goalsAwayTeam': 1,
    'score': {'halftime': '1-0',
     'fulltime': '3-1',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3377,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2019-04-03T18:45:00+00:00',
    'event_timestamp': 1554317100,
    'firstHalfStart': 1554317100,
    'secondHalfStart': 1554320700,
    'round': 'Regular Season - 28',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'JenS Vesting',
    'referee': 'Siemen Mulder, Netherlands',
    'homeTeam': {'team_id': 208,
     'team_name': 'Emmen',
     'logo': 'https://media.api-sports.io/football/teams/208.png'},
    'awayTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'goalsHomeTeam': 2,
    'goalsAwayTeam': 5,
    'score': {'halftime': '0-2',
     'fulltime': '2-5',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3382,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2019-04-06T16:30:00+00:00',
    'event_timestamp': 1554568200,
    'firstHalfStart': 1554568200,
    'secondHalfStart': 1554571800,
    'round': 'Regular Season - 29',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Koning Willem II Stadion',
    'referee': 'Danny Desmond Makkelie, Netherlands',
    'homeTeam': {'team_id': 195,
     'team_name': 'Willem II',
     'logo': 'https://media.api-sports.io/football/teams/195.png'},
    'awayTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'goalsHomeTeam': 1,
    'goalsAwayTeam': 4,
    'score': {'halftime': '1-2',
     'fulltime': '1-4',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3397,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2019-04-13T16:30:00+00:00',
    'event_timestamp': 1555173000,
    'firstHalfStart': 1555173000,
    'secondHalfStart': 1555176600,
    'round': 'Regular Season - 30',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Johan Cruijff Arena',
    'referee': 'Pol van Boekel, Netherlands',
    'homeTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'awayTeam': {'team_id': 196,
     'team_name': 'Excelsior',
     'logo': 'https://media.api-sports.io/football/teams/196.png'},
    'goalsHomeTeam': 6,
    'goalsAwayTeam': 2,
    'score': {'halftime': '3-1',
     'fulltime': '6-2',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3405,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2019-04-20T16:30:00+00:00',
    'event_timestamp': 1555777800,
    'firstHalfStart': 1555777800,
    'secondHalfStart': 1555781400,
    'round': 'Regular Season - 31',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Hitachi Capital Mobility Stadium',
    'referee': 'Dennis Higler, Netherlands',
    'homeTeam': {'team_id': 202,
     'team_name': 'Groningen',
     'logo': 'https://media.api-sports.io/football/teams/202.png'},
    'awayTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'goalsHomeTeam': 0,
    'goalsAwayTeam': 1,
    'score': {'halftime': '0-0',
     'fulltime': '0-1',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3413,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2019-04-23T18:45:00+00:00',
    'event_timestamp': 1556045100,
    'firstHalfStart': 1556045100,
    'secondHalfStart': 1556048700,
    'round': 'Regular Season - 32',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Johan Cruijff Arena',
    'referee': 'Jochem Kamphuis, Netherlands',
    'homeTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'awayTeam': {'team_id': 200,
     'team_name': 'Vitesse',
     'logo': 'https://media.api-sports.io/football/teams/200.png'},
    'goalsHomeTeam': 4,
    'goalsAwayTeam': 2,
    'score': {'halftime': '1-0',
     'fulltime': '4-2',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3425,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2019-05-12T12:30:00+00:00',
    'event_timestamp': 1557664200,
    'firstHalfStart': 1557664200,
    'secondHalfStart': 1557667800,
    'round': 'Regular Season - 34',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'Johan Cruijff Arena',
    'referee': 'Pol van Boekel, Netherlands',
    'homeTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'awayTeam': {'team_id': 207,
     'team_name': 'Utrecht',
     'logo': 'https://media.api-sports.io/football/teams/207.png'},
    'goalsHomeTeam': 4,
    'goalsAwayTeam': 1,
    'score': {'halftime': '2-1',
     'fulltime': '4-1',
     'extratime': None,
     'penalty': None}},
   {'fixture_id': 3417,
    'league_id': 10,
    'league': {'name': 'Eredivisie',
     'country': 'Netherlands',
     'logo': 'https://media.api-sports.io/football/leagues/88.png',
     'flag': 'https://media.api-sports.io/flags/nl.svg'},
    'event_date': '2019-05-15T17:30:00+00:00',
    'event_timestamp': 1557941400,
    'firstHalfStart': 1557941400,
    'secondHalfStart': 1557945000,
    'round': 'Regular Season - 33',
    'status': 'Match Finished',
    'statusShort': 'FT',
    'elapsed': 90,
    'venue': 'De Vijverberg',
    'referee': 'Danny Desmond Makkelie, Netherlands',
    'homeTeam': {'team_id': 199,
     'team_name': 'De Graafschap',
     'logo': 'https://media.api-sports.io/football/teams/199.png'},
    'awayTeam': {'team_id': 194,
     'team_name': 'Ajax',
     'logo': 'https://media.api-sports.io/football/teams/194.png'},
    'goalsHomeTeam': 1,
    'goalsAwayTeam': 4,
    'score': {'halftime': '1-2',
     'fulltime': '1-4',
     'extratime': None,
     'penalty': None}}]}}

# %%
end_score = []
for i in range(0,34):
    end_score.append(z['api']['fixtures'][i]['score']['fulltime'])

# %%
end_score = pd.DataFrame(end_score)

# %%
end_score
# Out:
#       0
# 0   1-1
# 1   0-1
# 2   5-0
# 3   0-4
# 4   3-0
# 5   3-0
# 6   0-2
# 7   5-0
# 8   0-4
# 9   3-0
# 10  2-0
# 11  1-7
# 12  0-3
# 13  5-1
# 14  1-4
# 15  8-0
# 16  1-3
# 17  4-4
# 18  6-2
# 19  6-0
# 20  1-0
# 21  5-0
# 22  1-5
# 23  4-0
# 24  2-1
# 25  1-0
# 26  3-1
# 27  2-5
# 28  1-4
# 29  6-2
# 30  0-1
# 31  4-2
# 32  4-1
# 33  1-4

# %%
end_score.to_csv('Raw_Data/ajax_stats_endscore.csv', sep= ',')

# %%
full_response
# Out:
# [{'api': {'results': 16,
#    'statistics': {'Shots on Goal': {'home': '7', 'away': '2'},
#     'Shots off Goal': {'home': '6', 'away': '6'},
#     'Total Shots': {'home': '17', 'away': '11'},
#     'Blocked Shots': {'home': '4', 'away': '3'},
#     'Shots insidebox': {'home': '9', 'away': '5'},
#     'Shots outsidebox': {'home': '8', 'away': '6'},
#     'Fouls': {'home': '13', 'away': '25'},
#     'Corner Kicks': {'home': '12', 'away': '7'},
#     'Offsides': {'home': None, 'away': None},
#     'Ball Possession': {'home': '65%', 'away': '35%'},
#     'Yellow Cards': {'home': '0', 'away': '4'},
#     'Red Cards': {'home': '0', 'away': '0'},
#     'Goalkeeper Saves': {'home': '1', 'away': '7'},
#     'Total passes': {'home': '547', 'away': '291'},
#     'Passes accurate': {'home': '453', 'away': '203'},
#     'Passes %': {'home': '83%', 'away': '70%'}}}},
#  {'api': {'results': 16,
#    'statistics': {'Shots on Goal': {'home': '1', 'away': '9'},
# ...
