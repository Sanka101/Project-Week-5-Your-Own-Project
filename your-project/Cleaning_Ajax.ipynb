# %%
import pandas as pd
import numpy as np

# %%
hometeam=  pd.read_csv("Raw_Data/ajax_stats_hometeam.csv", sep=",", index_col= False)

# %%
hometeam = hometeam[['team_id','team_name']]

# %%
hometeam
# Out:
#     team_id        team_name
# 0       194             Ajax
# 1       204        VVV Venlo
# 2       194             Ajax
# 3       200          Vitesse
# 4       194             Ajax
# 5       197    PSV Eindhoven
# 6       205  Fortuna Sittard
# 7       194             Ajax
# 8       210       Heerenveen
# 9       194             Ajax
# 10      194             Ajax
# 11      196        Excelsior
# 12      203        NAC Breda
# 13      194             Ajax
# 14      193       PEC Zwolle
# 15      194             Ajax
# 16      207          Utrecht
# 17      194             Ajax
# 18      209        Feyenoord
# 19      194             Ajax
# 20      206         Heracles
# 21      194             Ajax
# 22      198     ADO Den Haag
# 23      194             Ajax
# 24      194             Ajax
# 25      201       AZ Alkmaar
# 26      194             Ajax
# 27      208            Emmen
# 28      195        Willem II
# 29      194             Ajax
# 30      202        Groningen
# ...

# %%
stats_ajax = pd.read_csv("Raw_Data/ajax_stats_ha.csv", sep=",", index_col= False)

# %%
stats_ajax['Shots on Goal'][1]
# Out:
# "{'home': '1', 'away': '9'}"

# %%
home= []
for i in range(0,34):
    if hometeam['team_name'][i] == 'Ajax':
        home.append('Home')
    else:
        home.append('Away')
        
home
# Out:
# ['Home',
#  'Away',
#  'Home',
#  'Away',
#  'Home',
#  'Away',
#  'Away',
#  'Home',
#  'Away',
#  'Home',
#  'Home',
#  'Away',
#  'Away',
#  'Home',
#  'Away',
#  'Home',
#  'Away',
#  'Home',
#  'Away',
#  'Home',
#  'Away',
#  'Home',
#  'Away',
#  'Home',
#  'Home',
#  'Away',
#  'Home',
#  'Away',
#  'Away',
#  'Home',
#  'Away',
#  'Home',
#  'Home',
#  'Away']

# %%
stats_ajax
# Out:
#     Unnamed: 0                Shots on Goal               Shots off Goal  \
# 0            0   {'home': '7', 'away': '2'}   {'home': '6', 'away': '6'}
# 1            1   {'home': '1', 'away': '9'}   {'home': '5', 'away': '8'}
# 2            2  {'home': '10', 'away': '2'}   {'home': '8', 'away': '2'}
# 3            3   {'home': '7', 'away': '8'}  {'home': '11', 'away': '6'}
# 4            4   {'home': '6', 'away': '2'}   {'home': '8', 'away': '4'}
# 5            5   {'home': '8', 'away': '4'}   {'home': '4', 'away': '4'}
# 6            6   {'home': '5', 'away': '4'}   {'home': '4', 'away': '8'}
# 7            7  {'home': '11', 'away': '3'}   {'home': '8', 'away': '1'}
# 8            8  {'home': '4', 'away': '10'}   {'home': '7', 'away': '6'}
# 9            9  {'home': '10', 'away': '2'}   {'home': '9', 'away': '4'}
# 10          10  {'home': '10', 'away': '0'}   {'home': '7', 'away': '3'}
# 11          11  {'home': '3', 'away': '12'}   {'home': '8', 'away': '8'}
# ...

# %%
stats_ajax.columns
# Out:
# Index(['Unnamed: 0', 'Shots on Goal', 'Shots off Goal', 'Total Shots',
#        'Blocked Shots', 'Shots insidebox', 'Shots outsidebox', 'Fouls',
#        'Corner Kicks', 'Offsides', 'Ball Possession', 'Yellow Cards',
#        'Red Cards', 'Goalkeeper Saves', 'Total passes', 'Passes accurate',
#        'Passes %'],
#       dtype='object')

# %%
home = pd.DataFrame(home)

# %%
ajax_merge = pd.merge(home,stats_ajax,left_index=True, right_index= True)

# %%
ajax_merge
# Out:
#        0  Unnamed: 0                Shots on Goal  \
# 0   Home           0   {'home': '7', 'away': '2'}
# 1   Away           1   {'home': '1', 'away': '9'}
# 2   Home           2  {'home': '10', 'away': '2'}
# 3   Away           3   {'home': '7', 'away': '8'}
# 4   Home           4   {'home': '6', 'away': '2'}
# 5   Away           5   {'home': '8', 'away': '4'}
# 6   Away           6   {'home': '5', 'away': '4'}
# 7   Home           7  {'home': '11', 'away': '3'}
# 8   Away           8  {'home': '4', 'away': '10'}
# 9   Home           9  {'home': '10', 'away': '2'}
# 10  Home          10  {'home': '10', 'away': '0'}
# 11  Away          11  {'home': '3', 'away': '12'}
# 12  Away          12   {'home': '3', 'away': '5'}
# 13  Home          13  {'home': '12', 'away': '3'}
# 14  Away          14   {'home': '7', 'away': '6'}
# 15  Home          15  {'home': '17', 'away': '2'}
# 16  Away          16   {'home': '2', 'away': '7'}
# 17  Home          17   {'home': '9', 'away': '9'}
# ...

# %% [markdown]
# # Overall stats ajax

# %%
overall_ajax = pd.read_csv("Raw_Data/ajax_stats_overall.csv", sep=",", index_col= False)

# %%
overall_ajax
# Out:
#      Unnamed: 0                                 matchs  \
# 0  matchsPlayed  {'home': 17, 'away': 17, 'total': 34}
# 1          wins  {'home': 15, 'away': 13, 'total': 28}
# 2         draws     {'home': 2, 'away': 0, 'total': 2}
# 3         loses     {'home': 0, 'away': 4, 'total': 4}
# 4      goalsFor                                    NaN
# 5  goalsAgainst                                    NaN
#
#                                     goals  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4  {'home': 70, 'away': 49, 'total': 119}
# 5   {'home': 13, 'away': 19, 'total': 32}
#
#                                          goalsAvg
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# ...

# %% [markdown]
# # Endscore

# %%
ajax_stats_endscore = pd.read_csv("Raw_Data/ajax_stats_endscore.csv", sep=",", index_col= False)

# %%
ajax_stats_endscore = ajax_stats_endscore[['Unnamed: 0','0']]

# %%
ajax_stats_endscore = ajax_stats_endscore['0']

# %%
ajax_stats_endscore
# Out:
# 0     1-1
# 1     0-1
# 2     5-0
# 3     0-4
# 4     3-0
# 5     3-0
# 6     0-2
# 7     5-0
# 8     0-4
# 9     3-0
# 10    2-0
# 11    1-7
# 12    0-3
# 13    5-1
# 14    1-4
# 15    8-0
# 16    1-3
# 17    4-4
# 18    6-2
# 19    6-0
# 20    1-0
# 21    5-0
# 22    1-5
# 23    4-0
# 24    2-1
# 25    1-0
# 26    3-1
# 27    2-5
# 28    1-4
# 29    6-2
# 30    0-1
# 31    4-2
# 32    4-1
# 33    1-4
# Name: 0, dtype: object

# %% [markdown]
# # Final merge

# %%
pd.merge(ajax_merge,ajax_stats_endscore, left_index=True, right_index= True)
# Out:
#        0  Unnamed: 0                Shots on Goal  \
# 0   Home           0   {'home': '7', 'away': '2'}
# 1   Away           1   {'home': '1', 'away': '9'}
# 2   Home           2  {'home': '10', 'away': '2'}
# 3   Away           3   {'home': '7', 'away': '8'}
# 4   Home           4   {'home': '6', 'away': '2'}
# 5   Away           5   {'home': '8', 'away': '4'}
# 6   Away           6   {'home': '5', 'away': '4'}
# 7   Home           7  {'home': '11', 'away': '3'}
# 8   Away           8  {'home': '4', 'away': '10'}
# 9   Home           9  {'home': '10', 'away': '2'}
# 10  Home          10  {'home': '10', 'away': '0'}
# 11  Away          11  {'home': '3', 'away': '12'}
# 12  Away          12   {'home': '3', 'away': '5'}
# 13  Home          13  {'home': '12', 'away': '3'}
# 14  Away          14   {'home': '7', 'away': '6'}
# 15  Home          15  {'home': '17', 'away': '2'}
# 16  Away          16   {'home': '2', 'away': '7'}
# 17  Home          17   {'home': '9', 'away': '9'}
# ...

# %%
ajax_merge['Shots on Goal'][1]
# Out:
# "{'home': '1', 'away': '9'}"

# %% [markdown]
# # Try stats again

# %%
stats =[{'api': {'results': 16,
   'statistics': {'Shots on Goal': {'home': '7', 'away': '2'},
    'Shots off Goal': {'home': '6', 'away': '6'},
    'Total Shots': {'home': '17', 'away': '11'},
    'Blocked Shots': {'home': '4', 'away': '3'},
    'Shots insidebox': {'home': '9', 'away': '5'},
    'Shots outsidebox': {'home': '8', 'away': '6'},
    'Fouls': {'home': '13', 'away': '25'},
    'Corner Kicks': {'home': '12', 'away': '7'},
    'Offsides': {'home': None, 'away': None},
    'Ball Possession': {'home': '65%', 'away': '35%'},
    'Yellow Cards': {'home': '0', 'away': '4'},
    'Red Cards': {'home': '0', 'away': '0'},
    'Goalkeeper Saves': {'home': '1', 'away': '7'},
    'Total passes': {'home': '547', 'away': '291'},
    'Passes accurate': {'home': '453', 'away': '203'},
    'Passes %': {'home': '83%', 'away': '70%'}}}},
 {'api': {'results': 16,
   'statistics': {'Shots on Goal': {'home': '1', 'away': '9'},
    'Shots off Goal': {'home': '5', 'away': '8'},
    'Total Shots': {'home': '9', 'away': '18'},
    'Blocked Shots': {'home': '3', 'away': '1'},
    'Shots insidebox': {'home': '4', 'away': '10'},
    'Shots outsidebox': {'home': '5', 'away': '8'},
    'Fouls': {'home': '8', 'away': '9'},
    'Corner Kicks': {'home': '5', 'away': '7'},
    'Offsides': {'home': '0', 'away': '2'},
    'Ball Possession': {'home': '27%', 'away': '73%'},
    'Yellow Cards': {'home': '0', 'away': '1'},
    'Red Cards': {'home': '0', 'away': '0'},
    'Goalkeeper Saves': {'home': '8', 'away': '1'},
    'Total passes': {'home': '252', 'away': '666'},
    'Passes accurate': {'home': '166', 'away': '591'},
    'Passes %': {'home': '66%', 'away': '89%'}}}},
 {'api': {'results': 16,
   'statistics': {'Shots on Goal': {'home': '10', 'away': '2'},
    'Shots off Goal': {'home': '8', 'away': '2'},
    'Total Shots': {'home': '21', 'away': '6'},
    'Blocked Shots': {'home': '3', 'away': '2'},
    'Shots insidebox': {'home': '14', 'away': '2'},
    'Shots outsidebox': {'home': '7', 'away': '4'},
    'Fouls': {'home': '10', 'away': '9'},
    'Corner Kicks': {'home': '11', 'away': '1'},
    'Offsides': {'home': '1', 'away': '1'},
    'Ball Possession': {'home': '62%', 'away': '38%'},
    'Yellow Cards': {'home': '0', 'away': '1'},
    'Red Cards': {'home': '0', 'away': '0'},
    'Goalkeeper Saves': {'home':
'}}}},
 {'api': {'results': 16,
   'statistics': {'Shots on Goal': {'home': '12', 'away': '3'},
    'Shots off Goal': {'home': '9', 'away': '3'},
    'Total Shots': {'home': '25', 'away': '11'},
    'Blocked Shots': {'home': '4', 'away': '5'},
    'Shots insidebox': {'home': '17', 'away': '7'},
    'Shots outsidebox': {'home': '8', 'away': '4'},
    'Fouls': {'home': '8', 'away': '9'},
    'Corner Kicks': {'home': '5', 'away': '4'},
    'Offsides': {'home': None, 'away': None},
    'Ball Possession': {'home': '64%', 'away': '36%'},
    'Yellow Cards': {'home': '1', 'away': '4'},
    'Red Cards': {'home': None, 'away': None},
    'Goalkeeper Saves': {'home': '2', 'away': '8'},
    'Total passes': {'home': '609', 'away': '325'},
    'Passes accurate': {'home': '534', 'away': '248'},
    'Passes %': {'home': '88%', 'away': '76%'}}}},
 {'api': {'results': 16,
   'statistics': {'Shots on Goal': {'home': '3', 'away': '9'},
    'Shots off Goal': {'home': '5', 'away': '2'},
    'Total Shots': {'home': '11', 'away': '16'},
    'Blocked Shots': {'home': '3', 'away': '5'},
    'Shots insidebox': {'home': '6', 'away': '10'},
    'Shots outsidebox': {'home': '5', 'away': '6'},
    'Fouls': {'home': '8', 'away': '6'},
    'Corner Kicks': {'home': '2', 'away': '6'},
    'Offsides': {'home': '0', 'away': '3'},
    'Ball Possession': {'home': '37%', 'away': '63%'},
    'Yellow Cards': {'home': '1', 'away': '0'},
    'Red Cards': {'home': None, 'away': None},
    'Goalkeeper Saves': {'home': '5', 'away': '2'},
    'Total passes': {'home': '329', 'away': '558'},
    'Passes accurate': {'home': '240', 'away': '478'},
    'Passes %': {'home': '73%', 'away': '86%'}}}}]

# %%
stats_list =[]
for i in range(0,34):
    stats_list.append(stats[i]['api']['statistics'])
stats_list
# Out:
# [{'Shots on Goal': {'home': '7', 'away': '2'},
#   'Shots off Goal': {'home': '6', 'away': '6'},
#   'Total Shots': {'home': '17', 'away': '11'},
#   'Blocked Shots': {'home': '4', 'away': '3'},
#   'Shots insidebox': {'home': '9', 'away': '5'},
#   'Shots outsidebox': {'home': '8', 'away': '6'},
#   'Fouls': {'home': '13', 'away': '25'},
#   'Corner Kicks': {'home': '12', 'away': '7'},
#   'Offsides': {'home': None, 'away': None},
#   'Ball Possession': {'home': '65%', 'away': '35%'},
#   'Yellow Cards': {'home': '0', 'away': '4'},
#   'Red Cards': {'home': '0', 'away': '0'},
#   'Goalkeeper Saves': {'home': '1', 'away': '7'},
#   'Total passes': {'home': '547', 'away': '291'},
#   'Passes accurate': {'home': '453', 'away': '203'},
#   'Passes %': {'home': '83%', 'away': '70%'}},
#  {'Shots on Goal': {'home': '1', 'away': '9'},
#   'Shots off Goal': {'home': '5', 'away': '8'},
#   'Total Shots': {'home': '9', 'away': '18'},
#   'Blocked Shots': {'home': '3', 'away': '1'},
# ...

# %%
stats_list[1]
# Out:
# {'Shots on Goal': {'home': '1', 'away': '9'},
#  'Shots off Goal': {'home': '5', 'away': '8'},
#  'Total Shots': {'home': '9', 'away': '18'},
#  'Blocked Shots': {'home': '3', 'away': '1'},
#  'Shots insidebox': {'home': '4', 'away': '10'},
#  'Shots outsidebox': {'home': '5', 'away': '8'},
#  'Fouls': {'home': '8', 'away': '9'},
#  'Corner Kicks': {'home': '5', 'away': '7'},
#  'Offsides': {'home': '0', 'away': '2'},
#  'Ball Possession': {'home': '27%', 'away': '73%'},
#  'Yellow Cards': {'home': '0', 'away': '1'},
#  'Red Cards': {'home': '0', 'away': '0'},
#  'Goalkeeper Saves': {'home': '8', 'away': '1'},
#  'Total passes': {'home': '252', 'away': '666'},
#  'Passes accurate': {'home': '166', 'away': '591'},
#  'Passes %': {'home': '66%', 'away': '89%'}}

# %%
super_list= []
for i in range(0,34):
    a,b = zip(*stats_list[i].items())
    a = list(a)
    b = list(b)
    super_list.append(b)

super_list
# Out:
# [[{'home': '7', 'away': '2'},
#   {'home': '6', 'away': '6'},
#   {'home': '17', 'away': '11'},
#   {'home': '4', 'away': '3'},
#   {'home': '9', 'away': '5'},
#   {'home': '8', 'away': '6'},
#   {'home': '13', 'away': '25'},
#   {'home': '12', 'away': '7'},
#   {'home': None, 'away': None},
#   {'home': '65%', 'away': '35%'},
#   {'home': '0', 'away': '4'},
#   {'home': '0', 'away': '0'},
#   {'home': '1', 'away': '7'},
#   {'home': '547', 'away': '291'},
#   {'home': '453', 'away': '203'},
#   {'home': '83%', 'away': '70%'}],
#  [{'home': '1', 'away': '9'},
#   {'home': '5', 'away': '8'},
#   {'home': '9', 'away': '18'},
#   {'home': '3', 'away': '1'},
#   {'home': '4', 'away': '10'},
#   {'home': '5', 'away': '8'},
#   {'home': '8', 'away': '9'},
#   {'home': '5', 'away': '7'},
#   {'home': '0', 'away': '2'},
#   {'home': '27%', 'away': '73%'},
#   {'home': '0', 'away': '1'},
#   {'home': '0', 'away': '0'},
#   {'home': '8', 'away': '1'},
#   {'home': '252', 'away': '666'},
# ...

# %%
super_list[0]
# Out:
# [{'home': '7', 'away': '2'},
#  {'home': '6', 'away': '6'},
#  {'home': '17', 'away': '11'},
#  {'home': '4', 'away': '3'},
#  {'home': '9', 'away': '5'},
#  {'home': '8', 'away': '6'},
#  {'home': '13', 'away': '25'},
#  {'home': '12', 'away': '7'},
#  {'home': None, 'away': None},
#  {'home': '65%', 'away': '35%'},
#  {'home': '0', 'away': '4'},
#  {'home': '0', 'away': '0'},
#  {'home': '1', 'away': '7'},
#  {'home': '547', 'away': '291'},
#  {'home': '453', 'away': '203'},
#  {'home': '83%', 'away': '70%'}]

# %%
super_list[1][2]['home']
# Out:
# '9'

# %%
clean_stats_ajax= []

for i in range(0,34):
    if home[i] == 'Home':
        for j in range(0,16):
            clean_stats_ajax.append(super_list[i][j]['home'])
    elif home[i] == 'Away':
        for k in range(0,16):
            clean_stats_ajax.append(super_list[i][k]['away'])
        
clean_stats_ajax
# Out:
# ['7',
#  '6',
#  '17',
#  '4',
#  '9',
#  '8',
#  '13',
#  '12',
#  None,
#  '65%',
#  '0',
#  '0',
#  '1',
#  '547',
#  '453',
#  '83%',
#  '9',
#  '8',
#  '18',
#  '1',
#  '10',
#  '8',
#  '9',
#  '7',
#  '2',
#  '73%',
#  '1',
#  '0',
#  '1',
#  '666',
#  '591',
#  '89%',
#  '10',
#  '8',
#  '21',
#  '3',
#  '14',
#  '7',
#  '10',
#  '11',
#  '1',
#  '62%',
#  '0',
#  '0',
#  '2',
#  '636',
#  '545',
#  '86%',
#  '8',
#  '6',
#  '16',
#  '2',
#  '6',
#  '10',
#  '15',
#  '5',
#  '2',
#  '56%',
#  '0',
#  '0',
#  '7',
#  '463',
#  '379',
#  '82%',
#  '6',
#  '8',
#  '18',
#  '4',
#  '12',
#  '6',
#  '6',
#  '4',
#  '1',
#  '71%',
#  '2',
#  '0',
#  '2',
#  '698',
#  '616',
#  '88%',
#  '4',
#  '4',
#  '15',
#  '7',
#  '10',
#  '5',
#  '12',
#  '6',
#  '1',
#  '66%',
#  '2',
#  '0',
#  '5',
#  '548',
#  '459',
#  '84%',
#  '4',
#  '8',
#  '17',
#  '5',
#  '13',
#  '4',
#  '12',
#  '8',
#  '4',
#  '57%',
#  '2',
#  '0',
#  '5',
#  '530',
#  '432',
#  '82%',
#  '11',
#  '8',
#  '23',
# ...

# %%
# 544/
len(clean_stats_ajax)/16
# Out:
# 34.0

# %%
for i in range(0, len(clean_stats_ajax), 16):
    chunk = clean_stats_ajax[i:i + 16]
    print(chunk)
# Out:
# ['7', '6', '17', '4', '9', '8', '13', '12', None, '65%', '0', '0', '1', '547', '453', '83%']
# ['9', '8', '18', '1', '10', '8', '9', '7', '2', '73%', '1', '0', '1', '666', '591', '89%']
# ['10', '8', '21', '3', '14', '7', '10', '11', '1', '62%', '0', '0', '2', '636', '545', '86%']
# ['8', '6', '16', '2', '6', '10', '15', '5', '2', '56%', '0', '0', '7', '463', '379', '82%']
# ['6', '8', '18', '4', '12', '6', '6', '4', '1', '71%', '2', '0', '2', '698', '616', '88%']
# ['4', '4', '15', '7', '10', '5', '12', '6', '1', '66%', '2', '0', '5', '548', '459', '84%']
# ['4', '8', '17', '5', '13', '4', '12', '8', '4', '57%', '2', '0', '5', '530', '432', '82%']
# ['11', '8', '23', '4', '15', '8', '11', '6', '2', '57%', '2', '0', '3', '514', '441', '86%']
# ['10', '6', '17', '1', '9', '8', '13', '10', '0', '66%', '1', '0', '4', '598', '505', '84%']
# ['10', '9', '28', '9', '16', '12', '8', '13', '2', '69%', '1', '0', '2', '670', '598', '89%']
# ...

# %%
all_rows =[ ['7', '6', '17', '4', '9', '8', '13', '12', None, '65%', '0', '0', '1', '547', '453', '83%'],
['9', '8', '18', '1', '10', '8', '9', '7', '2', '73%', '1', '0', '1', '666', '591', '89%'],
['10', '8', '21', '3', '14', '7', '10', '11', '1', '62%', '0', '0', '2', '636', '545', '86%'],
['8', '6', '16', '2', '6', '10', '15', '5', '2', '56%', '0', '0', '7', '463', '379', '82%'],
['6', '8', '18', '4', '12', '6', '6', '4', '1', '71%', '2', '0', '2', '698', '616', '88%'],
['4', '4', '15', '7', '10', '5', '12', '6', '1', '66%', '2', '0', '5', '548', '459', '84%'],
['4', '8', '17', '5', '13', '4', '12', '8', '4', '57%', '2', '0', '5', '530', '432', '82%'],
['11', '8', '23', '4', '15', '8', '11', '6', '2', '57%', '2', '0', '3', '514', '441', '86%'],
['10', '6', '17', '1', '9', '8', '13', '10', '0', '66%', '1', '0', '4', '598', '505', '84%'],
['10', '9', '28', '9', '16', '12', '8', '13', '2', '69%', '1', '0', '2', '670', '598', '89%'],
['10', '7', '21', '4', '7', '14', '8', '5', '5', '61%', '0', '0', '0', '618', '528', '85%'],
['12', '8', '29', '9', '22', '7', '4', '15', '2', '63%', '0', '0', '2', '561', '482', '86%'],
['5', '8', '16', '3', '12', '4', '6', '7', '4', '74%', '1', '0', '3', '763', '676', '89%'],
['12', '11', '32', '9', '19', '13', '11', '19', '0', '72%', None, '0', '2', '609', '533', '88%'],
['6', '7', '14', '1', '9', '5', '7', '7', '3', '67%', '3', '0', '7', '530', '468', '88%'],
['17', '13', '35', '5', '21', '14', '3', '14', None, '73%', '0', '0', '2', '767', '681', '89%'],
['7', '4', '17', '6', '11', '6', '8', '9', '2', '64%', '2', '0', '1', '502', '396', '79%'],
['9', '12', '27', '6', '21', '6', '7', '11', '2', '67%', '0', '0', '5', '522', '440', '84%'],
['7', '4', '16', '5', '10', '6', '14', '5', '0', '51%', None, '0', '3', '411', '334', '81%'],
['11', '5', '23', '7', '13', '10', '7', '4', '1', '68%', '0', '0', '1', '651', '580', '89%'],
['7', '11', '22', '4', '14', '8', '12', '10', '1', '64%', '1', '0', '2', '527', '425', '81%'],
['10', '11', '33', '12', '23', '10', '9', '13', '1', '72%', '1', '0', '2', '661', '587', '89%'],
['11', '3', '17', '3', '9', '8', '14', '8', '1', '63%', '1', '0', '0', '501', '412', '82%'],
['8', '11', '21', '2', '11', '10', '15', '7', '1', '67%', None, None, '2', '762', '681', '89%'],
['7', '9', '17', '1', '10', '7', '9', '7', None, '59%', '2', None, '2', '540', '465', '86%'],
['6', '5', '15', '4', '7', '8', '13', '7', '3', '65%', '1', None, '5', '546', '436', '80%'],
['7', '3', '16', '6', '8', '8', '9', '4', '0', '49%', '3', '1', '2', '420', '304', '72%'],
['10', '5', '17', '2', '13', '4', '9', '4', None, '62%', '1', None, '3', '605', '509', '84%'],
['5', '4', '13', '4', '7', '6', '15', '1', '1', '55%', '0', None, '3', '527', '415', '79%'],
['13', '5', '22', '4', '19', '3', '9', '7', '3', '60%', '2', None, '2', '609', '500', '82%'],
['5', '5', '16', '6', '11', '5', '7', '6', '3', '61%', '3', '1', '2', '472', '349', '74%'],
['9', '5', '20', '6', '15', '5', '15', '5', '3', '56%', '2', None, '2', '526', '450', '86%'],
['12', '9', '25', '4', '17', '8', '8', '5', None, '64%', '1', None, '2', '609', '534', '88%'],
['9', '2', '16', '5', '10', '6', '6', '6', '3', '63%', '0', None, '2', '558', '478', '86%'] ]

# %%
all_rows
# Out:
# [['7',
#   '6',
#   '17',
#   '4',
#   '9',
#   '8',
#   '13',
#   '12',
#   None,
#   '65%',
#   '0',
#   '0',
#   '1',
#   '547',
#   '453',
#   '83%'],
#  ['9',
#   '8',
#   '18',
#   '1',
#   '10',
#   '8',
#   '9',
#   '7',
#   '2',
#   '73%',
#   '1',
#   '0',
#   '1',
#   '666',
#   '591',
#   '89%'],
#  ['10',
#   '8',
#   '21',
#   '3',
#   '14',
#   '7',
#   '10',
#   '11',
#   '1',
#   '62%',
#   '0',
#   '0',
#   '2',
#   '636',
#   '545',
#   '86%'],
#  ['8',
#   '6',
#   '16',
#   '2',
#   '6',
#   '10',
#   '15',
#   '5',
#   '2',
#   '56%',
#   '0',
#   '0',
#   '7',
#   '463',
#   '379',
#   '82%'],
#  ['6',
#   '8',
#   '18',
#   '4',
#   '12',
#   '6',
#   '6',
#   '4',
#   '1',
#   '71%',
#   '2',
#   '0',
#   '2',
#   '698',
#   '616',
#   '88%'],
#  ['4',
#   '4',
#   '15',
#   '7',
#   '10',
#   '5',
#   '12',
#   '6',
#   '1',
#   '66%',
#   '2',
#   '0',
#   '5',
#   '548',
#   '459',
#   '84%'],
#  ['4',
#   '8',
#   '17',
#   '5',
#   '13',
#   '4',
# ...

# %%
pd.DataFrame(data=all_rows, columns=['Shots on Goal','Shots off Goal',
 'Total Shots',
 'Blocked Shots' ,
 'Shots insidebox' ,
 'Shots outsidebox' ,
 'Fouls' ,
 'Corner Kicks' ,
 'Offsides' ,
 'Ball Possession' ,
 'Yellow Cards' ,
 'Red Cards' ,
 'Goalkeeper Saves' ,
 'Total passes' ,
 'Passes accurate',
 'Passes %'])
# Out:
#    Shots on Goal Shots off Goal Total Shots Blocked Shots Shots insidebox  \
# 0              7              6          17             4               9
# 1              9              8          18             1              10
# 2             10              8          21             3              14
# 3              8              6          16             2               6
# 4              6              8          18             4              12
# 5              4              4          15             7              10
# 6              4              8          17             5              13
# 7             11              8          23             4              15
# 8             10              6          17             1               9
# 9             10              9          28             9              16
# 10            10              7          21             4               7
# 11            12              8          29             9              22
# ...

# %%
ajax_stat_clean = pd.DataFrame(data=all_rows, columns=['Shots on Goal','Shots off Goal',
 'Total Shots',
 'Blocked Shots' ,
 'Shots insidebox' ,
 'Shots outsidebox' ,
 'Fouls' ,
 'Corner Kicks' ,
 'Offsides' ,
 'Ball Possession' ,
 'Yellow Cards' ,
 'Red Cards' ,
 'Goalkeeper Saves' ,
 'Total passes' ,
 'Passes accurate',
 'Passes %'])

# %%
ajax_stat_clean.to_csv("Raw_Data/ajax_stat_clean.csv", sep= ',')

# %% [markdown]
# # Merge

# %%
first = pd.merge(ajax_stat_clean,ajax_stats_endscore, left_index=True, right_index= True)

# %%
home = pd.DataFrame(home)

# %%
final = pd.merge(home,first, left_index=True, right_index= True)

# %%
final.to_csv("Raw_Data/ajax_final_clean.csv", sep=',')

# %% [markdown]
# # Old doesnot work

# %%
keys,values = zip(*stats[1]['api']['statistics'].items())

# %%
ho,away = zip(*values)

# %%
type(keys)
# Out:
# tuple

# %%
values[1]['away']
# Out:
# '8'

# %%
home[0]
# Out:
# 'Home'

# %%
clean_stats_ajax= []

for i in range(0,34):
    if home[i] == 'Home':
        clean_stats_ajax.append(values[i]['home'])
    elif home[i] == 'Away':
        clean_stats_ajax.append(values[i]['away'])
        
clean_stats_ajax
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-103-c7afb35bcfa4> in <module>
#       5         clean_stats_ajax.append(values[i]['home'])
#       6     elif home[i] == 'Away':
# ----> 7         clean_stats_ajax.append(values[i]['away'])
#       8
#       9 clean_stats_ajax
#
# IndexError: tuple index out of range
